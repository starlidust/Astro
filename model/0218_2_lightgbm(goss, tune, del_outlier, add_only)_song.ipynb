# %% [markdown]
# # Tune_lgb
# * 제출결과 :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import log_loss
import lightgbm as lgb

# %%
path = "./data/" 
train_df = pd.read_csv(path+'train.csv',index_col=0)
test_df = pd.read_csv(path+'test.csv',index_col=0)
sample_submission_df = pd.read_csv(path+'sample_submission.csv',index_col=0)
pd.options.display.max_columns = 30

# %% [markdown]
# ## 전처리
#  - 이상치 확인 및 처리

# %%
train_df.describe()
# Out:
#              fiberID      psfMag_u       psfMag_g       psfMag_r  \
# count  199991.000000  1.999910e+05  199991.000000  199991.000000
# mean      360.830152 -6.750146e+00      18.675373      18.401235
# std       225.305890  1.187678e+04     155.423024     127.128078
# min         1.000000 -5.310802e+06  -40022.466071  -27184.795793
# 25%       174.000000  1.965259e+01      18.701180      18.048572
# 50%       349.000000  2.087136e+01      19.904235      19.454492
# 75%       526.000000  2.216043e+01      21.150297      20.515936
# max      1000.000000  1.877392e+04    3538.984910    3048.110913
#
#             psfMag_i       psfMag_z    fiberMag_u     fiberMag_g  \
# count  199991.000000  199991.000000  1.999910e+05  199991.000000
# mean       18.043495      17.663526  1.084986e+01      19.072693
# std       116.622194     123.735298  4.172116e+03     749.256162
# min    -26566.310827  -24878.828280 -1.864766e+06 -215882.917191
# 25%        17.747663      17.425523  1.994040e+01      18.902851
# 50%        19.043895      18.611799  2.104910e+01      20.069038
# 75%        20.073528      19.883760  2.233754e+01      21.385830
# max      4835.218639    9823.740407  4.870154e+03  248077.513380
#
#           fiberMag_r     fiberMag_i     fiberMag_z     petroMag_u  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       19.134483      18.183331      18.000882      21.837903
# std        90.049058     122.378972     145.862346     789.472333
# min    -21802.656144  -20208.516262  -26505.602101  -24463.431833
# 25%        18.259352      17.903615      17.606148      19.247795
# 50%        19.631419      19.188763      18.710967      20.366848
# 75%        20.773911      20.331419      20.133179      21.797480
# max     12084.735440    8059.638535   18358.921741  298771.019041
#
#           petroMag_g     petroMag_r     petroMag_i     petroMag_z  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       18.454136      18.481525      17.686617      17.699207
# std       154.376277      97.240448     145.730872     142.691880
# min    -25958.752324  -23948.588523  -40438.184078  -30070.729379
# 25%        18.113933      17.479794      17.050294      16.804705
# 50%        19.586559      19.182789      18.693370      18.174592
# 75%        21.004397      20.457491      20.019112      19.807652
# max     12139.815877    7003.136546    9772.190537   17403.789263
#
#           modelMag_u     modelMag_g     modelMag_r     modelMag_i  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       20.110991      18.544375      18.181544      17.692395
# std       122.299062     161.728183     133.984475     131.183416
# min    -26236.578659  -36902.402336  -36439.638493  -38969.416822
# 25%        19.266214      18.076120      17.423425      16.977671
# 50%        20.406840      19.547674      19.143156      18.641756
# 75%        21.992898      20.962386      20.408140      19.968846
# max     14488.251976   10582.058590   12237.951703    4062.499371
#
#           modelMag_z
# count  199991.000000
# mean       17.189281
# std       133.685138
# min    -26050.710196
# 25%        16.705774
# 50%        18.100997
# 75%        19.819554
# max      7420.534172

# %%
def del_outlier(data, min=0, max=60):
    up_idx_t=()
    dw_idx_t=()
    train_light = data.iloc[:,2:]
    for i in range(len(train_light.columns)):
        col = train_light.columns[i]
        up_idx_t+=tuple(data[data[col]>max].index)
        dw_idx_t+=tuple(data[data[col]<min].index)
    del_idx = set(up_idx_t+dw_idx_t)
    
    return data[~data.index.isin(del_idx)]

# %%
train_df = del_outlier(train_df, min=-60, max=60)

# %%
train_df.describe()
# Out:
#              fiberID       psfMag_u       psfMag_g       psfMag_r  \
# count  199805.000000  199805.000000  199805.000000  199805.000000
# mean      360.874257      20.984096      19.860971      19.286994
# std       225.326886       2.084378       1.868696       1.721250
# min         1.000000     -12.978725     -19.537079     -43.795556
# 25%       174.000000      19.652802      18.701527      18.048615
# 50%       349.000000      20.870785      19.903867      19.454103
# 75%       526.000000      22.158644      21.148771      20.515044
# max      1000.000000      53.410871      54.250456      54.501228
#
#             psfMag_i       psfMag_z     fiberMag_u     fiberMag_g  \
# count  199805.000000  199805.000000  199805.000000  199805.000000
# mean       18.872327      18.612319      21.171538      20.089746
# std         1.628469       1.684458       1.982522       1.842191
# min        -6.406284      -6.793444     -55.669722      -8.294703
# 25%        17.747666      17.425886      19.941482      18.903532
# 50%        19.043575      18.611026      21.049142      20.069213
# 75%        20.072993      19.883188      22.336839      21.385460
# max        49.883443      42.136572      54.055822      37.745406
#
#           fiberMag_r     fiberMag_i     fiberMag_z     petroMag_u  \
# count  199805.000000  199805.000000  199805.000000  199805.000000
# mean       19.505260      19.087316      18.828446      20.710347
# std         1.706138       1.626217       1.676483       2.441525
# min       -11.531777      10.646672       8.049850     -50.847000
# 25%        18.259827      17.904548      17.607016      19.248446
# 50%        19.632080      19.189421      18.711351      20.366762
# 75%        20.773880      20.331692      20.133244      21.795629
# max        32.574603      42.002047      36.498179      58.298437
#
#           petroMag_g     petroMag_r     petroMag_i     petroMag_z  \
# count  199805.000000  199805.000000  199805.000000  199805.000000
# mean       19.600430      19.005845      18.605146      18.391528
# std         2.098483       1.971022       1.906945       2.056474
# min       -52.501232     -56.256807     -34.494076     -45.646493
# 25%        18.114513      17.480249      17.051207      16.805175
# 50%        19.586264      19.182726      18.693855      18.173881
# 75%        21.002840      20.456383      20.018679      19.806769
# max        58.042137      55.633809      59.835880      57.578250
#
#           modelMag_u     modelMag_g     modelMag_r     modelMag_i  \
# count  199805.000000  199805.000000  199805.000000  199805.000000
# mean       20.731087      19.530585      18.939735      18.520452
# std         2.187267       1.959114       1.859963       1.796639
# min         3.444448      12.498143      10.286917      11.337467
# 25%        19.265847      18.075890      17.423282      16.977685
# 50%        20.405706      19.546802      19.142725      18.641701
# 75%        21.990515      20.960706      20.407299      19.968434
# max        49.487277      59.987842      33.666494      45.783550
#
#           modelMag_z
# count  199805.000000
# mean       18.276576
# std         1.864622
# min        10.977328
# 25%        16.705562
# 50%        18.100568
# 75%        19.819179
# max        48.276514

# %%
train_df.columns
# Out:
# Index(['type', 'fiberID', 'psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'],
#       dtype='object')

# %% [markdown]
# ## DATA Setting

# %%
column_number = {}
number_columns = {}
for i, column in enumerate(sample_submission_df.columns):
    column_number[column] = i
    number_columns[i] = column
    
    
def to_number(x, dic):
    return dic[x]

train_df['type_num'] = train_df['type'].apply(lambda x: to_number(x, column_number))

# %%
def add_minus_feature_all(data,test = False):
    from itertools import combinations
    n = 0
    for count in range(5,21,5):
        s = 2
        if test == True :
            s = 1
        selected = data.columns[s:].values[n:count]
        mag = str.split(selected[0],'_')[0]
        for combi in list(combinations(selected,2)):
            name_1st = str.split(combi[0],'_')[1]
            name_2nd = str.split(combi[1],'_')[1]
            data[mag+"_"+name_1st+"-"+name_2nd] = data[combi[0]]-data[combi[1]]
        n=count
    return data

# %%
def add_minus_feature(data,test = False):
    '''
    근접변수에 대해서만 컬럼생성 ex) 'fiberMag_u-g', 'fiberMag_g-r', 'fiberMag_r-i', 'fiberMag_i-z'
    각 mag에서 가장 높은값의 filter를 받아오는 "~~mag_MAX"생성
    결과 38개로 증가 
    '''
    from itertools import combinations
    n = 0
    m = 0
    for count in range(5,21,5):
        s = 2
        if test == True :
            s = 1
        selected = data.columns[s:].values[n:count]
        mag = str.split(selected[0],'_')[0]
#         data[mag+"_MAX"] = data[selected].apply(lambda x : str.split(np.argmax(x),'_')[1],axis = 1)
        for i in range(0,len(selected)):        
            if i>0: 
                name_1st = str.split(m,'_')[1]
                name_2nd = str.split(selected[i],'_')[1]
                data[mag+"_"+name_1st+"-"+name_2nd] = data[m]-data[selected[i]]
            m = selected[i]    
        n=count
    return data

# %%
train_df = add_minus_feature(train_df)
test_df = add_minus_feature(test_df,True)

# %%
# train_df.drop(columns=['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'], inplace=True)

# test_df.drop(columns=['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'], inplace=True)

# %%
train_X = train_df.drop(columns=['type', 'type_num', 'fiberID'], axis=1)
train_y = train_df['type_num']
test_X = test_df.drop(columns=['fiberID'], axis=1)

# %%
train_X.head()
# Out:
#      psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# id
# 0   23.198224  21.431953  21.314148  21.176553  21.171444   22.581309
# 1   21.431355  20.708104  20.678850  20.703420  20.473229   21.868797
# 2   17.851451  16.727898  16.679677  16.694640  16.641788   18.171890
# 3   20.789900  20.040371  19.926909  19.843840  19.463270   21.039030
# 4   26.454969  23.058767  21.471406  19.504961  18.389096   25.700632
#
#     fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  petroMag_g  \
# id
# 0    21.644453   21.657571   21.387653   21.572827   22.504317   21.431636
# 1    21.029773   20.967054   20.937731   21.063646   21.360701   20.778968
# 2    17.033098   16.999682   17.095999   17.076449   17.867253   16.738784
# 3    20.317165   20.217898   20.073852   19.794505   20.433907   19.993727
# 4    23.629122   21.742750   19.861718   18.810375   25.859229   22.426929
#
#     petroMag_r  petroMag_i  petroMag_z  ...  psfMag_g-r  psfMag_r-i  \
# id                                      ...
# 0    21.478312   21.145409   20.422446  ...    0.117805    0.137595
# 1    20.889705   20.639812   20.646660  ...    0.029254   -0.024570
# 2    16.688874   16.744210   16.808006  ...    0.048221   -0.014963
# 3    19.985531   19.750917   19.455117  ...    0.113462    0.083069
# 4    21.673551   19.610012   18.376141  ...    1.587361    1.966445
#
#     psfMag_i-z  fiberMag_u-g  fiberMag_g-r  fiberMag_r-i  fiberMag_i-z  \
# id
# 0     0.005109      0.936856     -0.013118      0.269918     -0.185174
# 1     0.230191      0.839024      0.062718      0.029324     -0.125915
# 2     0.052852      1.138792      0.033416     -0.096317      0.019550
# 3     0.380569      0.721865      0.099267      0.144046      0.279347
# 4     1.115864      2.071510      1.886372      1.881032      1.051343
#
#     petroMag_u-g  petroMag_g-r  petroMag_r-i  petroMag_i-z  modelMag_u-g  \
# id
# 0       1.072682     -0.046676      0.332902      0.722964      1.283708
# 1       0.581734     -0.110737      0.249893     -0.006847      0.734428
# 2       1.128468      0.049910     -0.055336     -0.063796      1.120628
# 3       0.440180      0.008197      0.234614      0.295800      0.769012
# 4       3.432300      0.753377      2.063539      1.233871      1.729059
#
#     modelMag_g-r  modelMag_r-i  modelMag_i-z
# id
# 0       0.101347      0.343582     -0.126735
# 1       0.004602      0.060537      0.181074
# 2       0.056186     -0.018929     -0.028751
# 3       0.111901      0.131685      0.205258
# 4       1.672651      1.988012      1.111675
#
# [5 rows x 36 columns]

# %%
train_X.columns
# Out:
# Index(['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z',
#        'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z',
#        'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z',
#        'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z',
#        'psfMag_u-g', 'psfMag_g-r', 'psfMag_r-i', 'psfMag_i-z', 'fiberMag_u-g',
#        'fiberMag_g-r', 'fiberMag_r-i', 'fiberMag_i-z', 'petroMag_u-g',
#        'petroMag_g-r', 'petroMag_r-i', 'petroMag_i-z', 'modelMag_u-g',
#        'modelMag_g-r', 'modelMag_r-i', 'modelMag_i-z'],
#       dtype='object')

# %%
# ## u-g, g-r, r-i, i-z 만 남기는게 좋지 않을까????
# train_X.drop(['psfMag_u-r','psfMag_u-i','psfMag_u-z','psfMag_g-i','psfMag_g-z','psfMag_r-z',
#              'fiberMag_u-r','fiberMag_u-i','fiberMag_u-z','fiberMag_g-i','fiberMag_g-z','fiberMag_r-z',
#              'petroMag_u-r','petroMag_u-i','petroMag_u-z','petroMag_g-i','petroMag_g-z','petroMag_r-z',
#              'modelMag_u-r','modelMag_u-i','modelMag_u-z','modelMag_g-i','modelMag_g-z','modelMag_r-z'] ,axis=1, inplace=True)

# test_X.drop(['psfMag_u-r','psfMag_u-i','psfMag_u-z','psfMag_g-i','psfMag_g-z','psfMag_r-z',
#              'fiberMag_u-r','fiberMag_u-i','fiberMag_u-z','fiberMag_g-i','fiberMag_g-z','fiberMag_r-z',
#              'petroMag_u-r','petroMag_u-i','petroMag_u-z','petroMag_g-i','petroMag_g-z','petroMag_r-z',
#              'modelMag_u-r','modelMag_u-i','modelMag_u-z','modelMag_g-i','modelMag_g-z','modelMag_r-z'] ,axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_y, test_size=0.3, random_state=59,stratify = train_y)

# %%
# train_ds = lgb.Dataset(X_train, label = y_train, categorical_feature=['fiberID'])
# test_ds = lgb.Dataset(X_test, label = y_test, categorical_feature=['fiberID']) 
train_ds = lgb.Dataset(X_train, label = y_train)
test_ds = lgb.Dataset(X_test, label = y_test)

# %%
# #1번 0217
# params = {
#     'boosting_type': 'dart',
#     'objective': 'multiclass',
#     'num_class': train_y.nunique(),
#     'metric': {'multi_logloss','multi_logloss'},
#     'num_leaves': 25,
#     'learning_rate': 0.009,
#     'max_depth' : 11,
#     'random_state' : 59
# }

# %%
# #2번 0219 0.424
# params = {
# #     'boosting_type': 'dart',
#     'boosting_type': 'goss',
#     'objective': 'multiclass',
#     'num_class': train_y.nunique(),
#     'metric': {'multi_logloss','multi_logloss'},
#     'num_leaves': 25,
#     'feature_fraction': 0.75,
#     'subsample': 0.75,
#     'n_jobs': -1,
#     'seed': 1059,
#     'max_depth': 10,
#     'learning_rate': 0.01,
#     'top_rate': 0.01,
#     'other_rate': 0.005,
# #     'random_state' : 1059
# }

# %%
#3번 0219 
train_ds = lgb.Dataset(X_train, label = y_train)
test_ds = lgb.Dataset(X_test, label = y_test) 

params = {
    'boosting_type': 'dart',
#     'boosting_type': 'goss',
    'objective': 'multiclass',
    'num_class': train_y.nunique(),
    'metric': {'multi_logloss','multi_logloss'},
    'num_leaves': 50,
    'feature_fraction': 0.75,
    'subsample': 0.75,
    'n_jobs': -1,
    'seed': 1059,
    'max_depth': 11,
    'learning_rate': 0.009,
    'max_drop': 30,
    'skip_drop': 0.3,
#     'random_state' : 1059
}

# %% [markdown]
# ## Modeling

# %%
evaluation_results = {}
lgmb_model = lgb.train(params, train_ds,num_boost_round= 7000, 
                       valid_sets = [train_ds,test_ds], valid_names=['Train', 'Test'],
                       evals_result=evaluation_results,
                       verbose_eval=50, early_stopping_rounds=20)
# Out:
# [50]	Train's multi_logloss: 2.0627	Test's multi_logloss: 2.07009
# [100]	Train's multi_logloss: 2.02887	Test's multi_logloss: 2.03711
# [150]	Train's multi_logloss: 1.90269	Test's multi_logloss: 1.91283
# [200]	Train's multi_logloss: 1.83215	Test's multi_logloss: 1.84337
# [250]	Train's multi_logloss: 1.81547	Test's multi_logloss: 1.827
# [300]	Train's multi_logloss: 1.74157	Test's multi_logloss: 1.75436
# [350]	Train's multi_logloss: 1.73815	Test's multi_logloss: 1.75109
# [400]	Train's multi_logloss: 1.6904	Test's multi_logloss: 1.70423
# [450]	Train's multi_logloss: 1.66889	Test's multi_logloss: 1.68316
# [500]	Train's multi_logloss: 1.59252	Test's multi_logloss: 1.60792
# [550]	Train's multi_logloss: 1.53356	Test's multi_logloss: 1.55002
# [600]	Train's multi_logloss: 1.53649	Test's multi_logloss: 1.55306
# [650]	Train's multi_logloss: 1.43817	Test's multi_logloss: 1.45635
# [700]	Train's multi_logloss: 1.34675	Test's multi_logloss: 1.36649
# [750]	Train's multi_logloss: 1.25357	Test's multi_logloss: 1.27497
# [800]	Train's multi_logloss: 1.18513	Test's multi_logloss: 1.20795
# [850]	Train's multi_logloss: 1.15418	Test's multi_logloss: 1.17773
# [900]	Train's multi_logloss: 1.11938	Test's multi_logloss: 1.14378
# [950]	Train's multi_logloss: 1.07387	Test's multi_logloss: 1.09921
# [1000]	Train's multi_logloss: 1.02943	Test's multi_logloss: 1.05586
# [1050]	Train's multi_logloss: 0.970887	Test's multi_logloss: 0.998715
# [1100]	Train's multi_logloss: 0.959192	Test's multi_logloss: 0.987432
# [1150]	Train's multi_logloss: 0.964062	Test's multi_logloss: 0.992386
# [1200]	Train's multi_logloss: 0.919577	Test's multi_logloss: 0.949023
# [1250]	Train's multi_logloss: 0.902347	Test's multi_logloss: 0.932327
# [1300]	Train's multi_logloss: 0.885006	Test's multi_logloss: 0.915494
# [1350]	Train's multi_logloss: 0.848866	Test's multi_logloss: 0.880329
# [1400]	Train's multi_logloss: 0.816258	Test's multi_logloss: 0.848693
# [1450]	Train's multi_logloss: 0.844706	Test's multi_logloss: 0.876574
# [1500]	Train's multi_logloss: 0.820267	Test's multi_logloss: 0.852855
# [1550]	Train's multi_logloss: 0.805375	Test's multi_logloss: 0.838496
# [1600]	Train's multi_logloss: 0.767353	Test's multi_logloss: 0.801685
# [1650]	Train's multi_logloss: 0.749775	Test's multi_logloss: 0.784724
# [1700]	Train's multi_logloss: 0.709886	Test's multi_logloss: 0.746175
# [1750]	Train's multi_logloss: 0.713605	Test's multi_logloss: 0.749957
# [1800]	Train's multi_logloss: 0.675859	Test's multi_logloss: 0.713543
# [1850]	Train's multi_logloss: 0.648078	Test's multi_logloss: 0.686863
# [1900]	Train's multi_logloss: 0.631326	Test's multi_logloss: 0.670895
# [1950]	Train's multi_logloss: 0.621443	Test's multi_logloss: 0.661549
# [2000]	Train's multi_logloss: 0.601464	Test's multi_logloss: 0.642541
# [2050]	Train's multi_logloss: 0.583691	Test's multi_logloss: 0.625725
# [2100]	Train's multi_logloss: 0.579338	Test's multi_logloss: 0.621702
# [2150]	Train's multi_logloss: 0.563443	Test's multi_logloss: 0.606713
# [2200]	Train's multi_logloss: 0.548235	Test's multi_logloss: 0.592426
# [2250]	Train's multi_logloss: 0.534467	Test's multi_logloss: 0.579525
# [2300]	Train's multi_logloss: 0.523167	Test's multi_logloss: 0.569016
# [2350]	Train's multi_logloss: 0.502474	Test's multi_logloss: 0.54966
# [2400]	Train's multi_logloss: 0.492717	Test's multi_logloss: 0.540749
# [2450]	Train's multi_logloss: 0.487785	Test's multi_logloss: 0.536296
# [2500]	Train's multi_logloss: 0.473845	Test's multi_logloss: 0.523474
# [2550]	Train's multi_logloss: 0.471458	Test's multi_logloss: 0.521461
# [2600]	Train's multi_logloss: 0.454398	Test's multi_logloss: 0.505798
# [2650]	Train's multi_logloss: 0.443188	Test's multi_logloss: 0.495714
# [2700]	Train's multi_logloss: 0.434407	Test's multi_logloss: 0.487855
# [2750]	Train's multi_logloss: 0.423533	Test's multi_logloss: 0.478173
# [2800]	Train's multi_logloss: 0.416079	Test's multi_logloss: 0.471668
# [2850]	Train's multi_logloss: 0.405552	Test's multi_logloss: 0.462389
# [2900]	Train's multi_logloss: 0.397182	Test's multi_logloss: 0.45519
# [2950]	Train's multi_logloss: 0.396621	Test's multi_logloss: 0.454956
# [3000]	Train's multi_logloss: 0.396262	Test's multi_logloss: 0.454844
# [3050]	Train's multi_logloss: 0.395813	Test's multi_logloss: 0.454651
# [3100]	Train's multi_logloss: 0.388928	Test's multi_logloss: 0.448764
# [3150]	Train's multi_logloss: 0.385075	Test's multi_logloss: 0.445535
# [3200]	Train's multi_logloss: 0.376797	Test's multi_logloss: 0.438579
# [3250]	Train's multi_logloss: 0.37068	Test's multi_logloss: 0.433528
# [3300]	Train's multi_logloss: 0.365713	Test's multi_logloss: 0.429509
# [3350]	Train's multi_logloss: 0.36109	Test's multi_logloss: 0.425817
# [3400]	Train's multi_logloss: 0.358051	Test's multi_logloss: 0.423492
# [3450]	Train's multi_logloss: 0.35163	Test's multi_logloss: 0.418356
# [3500]	Train's multi_logloss: 0.347001	Test's multi_logloss: 0.414762
# [3550]	Train's multi_logloss: 0.343104	Test's multi_logloss: 0.41179
# [3600]	Train's multi_logloss: 0.339043	Test's multi_logloss: 0.408729
# [3650]	Train's multi_logloss: 0.337084	Test's multi_logloss: 0.407397
# [3700]	Train's multi_logloss: 0.334986	Test's multi_logloss: 0.405957
# [3750]	Train's multi_logloss: 0.329578	Test's multi_logloss: 0.401943
# [3800]	Train's multi_logloss: 0.327704	Test's multi_logloss: 0.400706
# [3850]	Train's multi_logloss: 0.324063	Test's multi_logloss: 0.398114
# [3900]	Train's multi_logloss: 0.325327	Test's multi_logloss: 0.399291
# [3950]	Train's multi_logloss: 0.320317	Test's multi_logloss: 0.395643
# [4000]	Train's multi_logloss: 0.319274	Test's multi_logloss: 0.395081
# [4050]	Train's multi_logloss: 0.316591	Test's multi_logloss: 0.393287
# [4100]	Train's multi_logloss: 0.313778	Test's multi_logloss: 0.391418
# [4150]	Train's multi_logloss: 0.311685	Test's multi_logloss: 0.390096
# [4200]	Train's multi_logloss: 0.309898	Test's multi_logloss: 0.389025
# [4250]	Train's multi_logloss: 0.307322	Test's multi_logloss: 0.38738
# [4300]	Train's multi_logloss: 0.301782	Test's multi_logloss: 0.383758
# [4350]	Train's multi_logloss: 0.30045	Test's multi_logloss: 0.383055
# [4400]	Train's multi_logloss: 0.299545	Test's multi_logloss: 0.382659
# [4450]	Train's multi_logloss: 0.298287	Test's multi_logloss: 0.381997
# [4500]	Train's multi_logloss: 0.295337	Test's multi_logloss: 0.380261
# [4550]	Train's multi_logloss: 0.294802	Test's multi_logloss: 0.380093
# [4600]	Train's multi_logloss: 0.293549	Test's multi_logloss: 0.379454
# [4650]	Train's multi_logloss: 0.291675	Test's multi_logloss: 0.378417
# [4700]	Train's multi_logloss: 0.291154	Test's multi_logloss: 0.378263
# [4750]	Train's multi_logloss: 0.288818	Test's multi_logloss: 0.376947
# [4800]	Train's multi_logloss: 0.286931	Test's multi_logloss: 0.375948
# [4850]	Train's multi_logloss: 0.285904	Test's multi_logloss: 0.375522
# [4900]	Train's multi_logloss: 0.283647	Test's multi_logloss: 0.374345
# [4950]	Train's multi_logloss: 0.282875	Test's multi_logloss: 0.374042
# [5000]	Train's multi_logloss: 0.280591	Test's multi_logloss: 0.37286
# [5050]	Train's multi_logloss: 0.279149	Test's multi_logloss: 0.372179
# [5100]	Train's multi_logloss: 0.276995	Test's multi_logloss: 0.371143
# [5150]	Train's multi_logloss: 0.275294	Test's multi_logloss: 0.370409
# [5200]	Train's multi_logloss: 0.274071	Test's multi_logloss: 0.369935
# [5250]	Train's multi_logloss: 0.271465	Test's multi_logloss: 0.368772
# [5300]	Train's multi_logloss: 0.269905	Test's multi_logloss: 0.368175
# [5350]	Train's multi_logloss: 0.268898	Test's multi_logloss: 0.367842
# [5400]	Train's multi_logloss: 0.267699	Test's multi_logloss: 0.367436
# [5450]	Train's multi_logloss: 0.266876	Test's multi_logloss: 0.367204
# [5500]	Train's multi_logloss: 0.266318	Test's multi_logloss: 0.367089
# [5550]	Train's multi_logloss: 0.263802	Test's multi_logloss: 0.366042
# [5600]	Train's multi_logloss: 0.262918	Test's multi_logloss: 0.365801
# [5650]	Train's multi_logloss: 0.261067	Test's multi_logloss: 0.365134
# [5700]	Train's multi_logloss: 0.259426	Test's multi_logloss: 0.364588
# [5750]	Train's multi_logloss: 0.258252	Test's multi_logloss: 0.364261
# [5800]	Train's multi_logloss: 0.257584	Test's multi_logloss: 0.364155
# [5850]	Train's multi_logloss: 0.256616	Test's multi_logloss: 0.363896
# [5900]	Train's multi_logloss: 0.255486	Test's multi_logloss: 0.363575
# [5950]	Train's multi_logloss: 0.254403	Test's multi_logloss: 0.363271
# [6000]	Train's multi_logloss: 0.253113	Test's multi_logloss: 0.362899
# [6050]	Train's multi_logloss: 0.252701	Test's multi_logloss: 0.362875
# [6100]	Train's multi_logloss: 0.250315	Test's multi_logloss: 0.362147
# [6150]	Train's multi_logloss: 0.249001	Test's multi_logloss: 0.361799
# [6200]	Train's multi_logloss: 0.248229	Test's multi_logloss: 0.361665
# [6250]	Train's multi_logloss: 0.246724	Test's multi_logloss: 0.361265
# [6300]	Train's multi_logloss: 0.245824	Test's multi_logloss: 0.361105
# [6350]	Train's multi_logloss: 0.245121	Test's multi_logloss: 0.360993
# [6400]	Train's multi_logloss: 0.244095	Test's multi_logloss: 0.3608
# [6450]	Train's multi_logloss: 0.2426	Test's multi_logloss: 0.360446
# [6500]	Train's multi_logloss: 0.240921	Test's multi_logloss: 0.360115
# [6550]	Train's multi_logloss: 0.240321	Test's multi_logloss: 0.360068
# [6600]	Train's multi_logloss: 0.240401	Test's multi_logloss: 0.360223
# [6650]	Train's multi_logloss: 0.239103	Test's multi_logloss: 0.359982
# [6700]	Train's multi_logloss: 0.238493	Test's multi_logloss: 0.359917
# [6750]	Train's multi_logloss: 0.237404	Test's multi_logloss: 0.35972
# [6800]	Train's multi_logloss: 0.236149	Test's multi_logloss: 0.35948
# [6850]	Train's multi_logloss: 0.235185	Test's multi_logloss: 0.359372
# [6900]	Train's multi_logloss: 0.233589	Test's multi_logloss: 0.359118
# [6950]	Train's multi_logloss: 0.232801	Test's multi_logloss: 0.359021
# [7000]	Train's multi_logloss: 0.231857	Test's multi_logloss: 0.358897

# %%
fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
axs[0].plot(evaluation_results['Train']['multi_logloss'], label='Train')
axs[0].plot(evaluation_results['Test']['multi_logloss'], label='Test')
axs[0].set_ylabel('Log loss')
axs[0].set_xlabel('Boosting round')
axs[0].set_title('Training performance')
axs[0].legend()

# Plot feature importance
importances = pd.DataFrame({'features': lgmb_model.feature_name(), 
                            'importance': lgmb_model.feature_importance()}).sort_values('importance', ascending=False).head(10)
axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
axs[1].set_xticks(np.arange(len(importances)))
axs[1].set_xticklabels(importances['features'])
axs[1].set_ylabel('Feature importance (# times used to split)')
axs[1].set_title('Feature importance')
plt.xticks(rotation=45)

plt.show()

# %%
train_y_pred = lgmb_model.predict(X_test)
real_y_pred = lgmb_model.predict(test_X)

# %%
#log_loss
log_loss(y_test,train_y_pred,labels= list(set(y_test)))
# Out:
# 0.358896767751708

# %%
feature_df = pd.DataFrame(lgmb_model.feature_importance(), index= train_X.columns,columns= ['importance']).sort_values('importance',ascending = False)
feature_df.head(10)
# Out:
#               importance
# modelMag_r-i      262803
# psfMag_u-g        259465
# modelMag_g-r      259129
# modelMag_u-g      255147
# fiberMag_g-r      248177
# psfMag_g-r        240298
# modelMag_i-z      238046
# fiberMag_u-g      235143
# fiberMag_r-i      231205
# psfMag_r-i        221347

# %%
submission = pd.DataFrame(data=real_y_pred, columns=sample_submission_df.columns, index=sample_submission_df.index)
submission.to_csv(f'submission_lightbgm_tune_outlier_add_only({log_loss(y_test,train_y_pred,labels= list(set(y_test)))}).csv', index=True)

# %% [markdown]
# ## Gridsearch_cv

# %%
# from sklearn.feature_selection import SelectKBest
# model_kbest = SelectKBest()
# from sklearn.pipeline import Pipeline

# %%
# #최적의 변수를 찾기 위한 KBest 함수 불러오기
# #파이프라인 구축
# pipe_lgbm = Pipeline([('lgbm',lgbm_c)])
# #파라미터 생성
# params_lgbm = {
#           "lgbm__max_depth": [15,20,25],
#          "lgbm__learning_rate": [0.001],
#          "lgbm__num_leaves": [15,20,25],
#          "lgbm__n_estimators": [200,300,400,500],
#          "lgbm__random_state": [42]}

# %%
# #최적의 파라미터 탐색
# from sklearn.model_selection import GridSearchCV
# grid_search = GridSearchCV(pipe_lgbm, param_grid = params_lgbm,
# #                           cv=3, n_jobs=-1, verbose=10)

# %%
# grid_search.fit(X_train, y_train)

# %%
# lgbm_grid = grid_search.best_estimator_
# lgbm_grid
