# %% [markdown]
# Index
# 1. [대회안내](#대회안내)
# 2. [데이터로드](#데이터로드)
# 3. [EDA](#EDA)
# 4. [Baseline_MLP](#Baseline_MLP)
# 5. [Baseline_RF](#Baseline_RF)

# %% [markdown]
# # 대회안내
# [출처-Dacon](https://dacon.io/competitions/official/235573/overview/description/)
#
# 1. 배경
#
# 최근 인류에게 다가온 빅데이터라는 단어는 우주와 천문학에게 낯설지 않습니다.
# 찰나의 순간에도 우주는 천문학적인 양의 데이터를 생산해왔고, 오래 전부터 천문학자들은 우주를 관측했으며, 그 방대함에 비례하는 데이터를 수집 및 분석했기 때문입니다.
# 슬론 디지털 천체 관측(Sloan Digital Sky Survey: 이하 SDSS)는 세계적 천체 관측 프로젝트로, 우주에 대한 천문학적인 규모의 데이터를 수집하고 있습니다.
# 이곳에서 수집한 데이터는 약 6,000개 논문에 사용되었고, 25만 회 이상 인용되었을 정도로 천문학에 큰 기여를 했습니다.
# 점점 거대해지는 규모에 따라 데이터 처리에는 머신러닝과 딥러닝 기법이 활용되기 시작했습니다.
# 여전히 우주에는 다양한 미지의 이야기가 남아있고, 오늘날 인간은 하늘에서 많은 데이터를 얻어낼 정도로 발전했습니다.
# 이 데이터를 분석하여 어쩌면 드러나지 않은 규칙이 여러분의 손끝에서 밝혀질 수 있습니다.
# 새로운 알고리즘을 통해 우주의 비밀을 찾아주세요!
#
# 2. 규칙
# 최대 팀 인원: 3명
# 최대 제출 횟수: 96회
# 일일 최대 제출: 3회
# 채점 방식: LogLoss
#
#     1. 평가
#         본 대회에서는 LogLoss로 제출 파일을 평가합니다.
#         a) 가채점 순위 : 대회 중 test 데이터의 30%로 채점합니다.
#         b) 최종 순위 : 가채점에서 사용하지 않은 나머지 test 데이터로 채점합니다. 대회 종료 후에 공개됩니다.
#         최종순위는 참가자가 선택한 파일로 채점되므로, 참가자는 자신이 채점 받고 싶은 제출 파일을 최종적으로 선택해야 합니다.
#     2. 외부 데이터
#         본 대회에는 어떠한 외부데이터 사용이 불가합니다.
#     3. 참가 방법
#         - 개인 참가 방법 : 팀 신청 없이, 자유롭게 제출 창에서 제출 가능
#         - 팀 참가 방법
#
#         a) 팀장, 팀원 모두 참여하기 버튼 클릭하기
#         b) 팀장이 각 팀원을 검색 (닉네임 or ID or 가입 이메일), 해당 팀원 합체 요청
#         c) 각 팀원은 팀장으로부터 온 팀 병합 요청 수락
#         d) 팀 참가 완료
#             * 한 번 팀으로 등록되면 어떠한 경우에도 팀 탈퇴 및 개인 참여가 불가능합니다.
#             * 하나의 대회에는 하나의 팀으로만 등록이 가능합니다.
#             * 팀의 수상 요건 충족 시 팀의 대표가 수상하게 됩니다.
#     4. 코드
#         1) 입상자는 코드 제출 필수. 제출 코드는 예측 결과를 리더보드 점수로 복원할 수 있어야 함
#         2) 코드 제출시 확장자가 R user는 R or .rmd. Python user는 .py or .ipynb
#         3) 코드에 ‘/data’ 데이터 입/출력 경로 포함 제출
#         4) 전체 프로세스를 일목요연하게 정리하여 주석을 포함하여 하나의 파일로 제출
#         5) 모든 코드는 오류 없이 실행되어야 함(라이브러리 로딩 코드 포함되어야 함).
#         6) 코드와 주석의 인코딩은 모두 UTF-8을 사용하여야 함
#     5. 토론(질문)
#         해당 대회에서는 대회 운영 및 데이터 이상에 관련된 질문 외에는 답변 드리지 않을 예정입니다.
#         결측치 처리 방법, 모델 구성 방법 등등 대회 운영 및 데이터 이상 외 질문은 토론 페이지를 통해 자유롭게 토론해 주시기 바랍니다.
#         * 데이콘 답변을 요청하는 경우 토론 제목에 [DACON 답변 요청] 문구를 넣어 질문을 올려 주시기바랍니다. 예) [DACON 답변 요청] 시상식은 언제 열리나요?
# 3. 컬럼 설명
#     * type(Source type) : 천체의 분류 예측을 해야하는 변수
#     * psfMag(Point spread function magnitudes): 먼 천체를 한 점으로 가정하여 측정한 빛의 밝기입니다.
#     * fiberMag(Fiber magnitudes) : 3인치 지름의 광섬유를 사용하여 광스펙트럼을 측정합니다. 광섬유를 통과하는 빛의 밝기입니다.
#     * petroMag(Petrosian Magnitudes) : 은하처럼 뚜렷한 표면이 없는 천체에서는 빛의 밝기를 측정하기 어렵습니다. 천체의 위치와 거리에 상관없이 빛의 밝기를 비교하기 위한 수치입니다.
#     * modelMag(Model magnitudes) : 천체 중심으로부터 특정 거리의 밝기입니다.
#     * fiberID : 관측에 사용된 광섬유의 구분자

# %% [markdown]
# # 데이터로드

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "./data/"
train_df = pd.read_csv(path+'train.csv',index_col=0)
test_df = pd.read_csv(path+'test.csv',index_col=0)
sample_submission_df = pd.read_csv(path+'sample_submission.csv',index_col=0)
pd.options.display.max_columns = 30

# %%
train_df.shape, test_df.shape
# Out:
# ((199991, 22), (10009, 21))

# %% [markdown]
# # EDA

# %%
train_df.head()
# Out:
#               type  fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i  \
# id
# 0              QSO      601  23.198224  21.431953  21.314148  21.176553
# 1              QSO      788  21.431355  20.708104  20.678850  20.703420
# 2              QSO      427  17.851451  16.727898  16.679677  16.694640
# 3              QSO      864  20.789900  20.040371  19.926909  19.843840
# 4   STAR_RED_DWARF      612  26.454969  23.058767  21.471406  19.504961
#
#      psfMag_z  fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  \
# id
# 0   21.171444   22.581309   21.644453   21.657571   21.387653   21.572827
# 1   20.473229   21.868797   21.029773   20.967054   20.937731   21.063646
# 2   16.641788   18.171890   17.033098   16.999682   17.095999   17.076449
# 3   19.463270   21.039030   20.317165   20.217898   20.073852   19.794505
# 4   18.389096   25.700632   23.629122   21.742750   19.861718   18.810375
#
#     petroMag_u  petroMag_g  petroMag_r  petroMag_i  petroMag_z  modelMag_u  \
# ...

# %%
#중위값 기준으로 대부분의 값이 20언저리임 
train_df.describe()
# Out:
#              fiberID      psfMag_u       psfMag_g       psfMag_r  \
# count  199991.000000  1.999910e+05  199991.000000  199991.000000
# mean      360.830152 -6.750146e+00      18.675373      18.401235
# std       225.305890  1.187678e+04     155.423024     127.128078
# min         1.000000 -5.310802e+06  -40022.466071  -27184.795793
# 25%       174.000000  1.965259e+01      18.701180      18.048572
# 50%       349.000000  2.087136e+01      19.904235      19.454492
# 75%       526.000000  2.216043e+01      21.150297      20.515936
# max      1000.000000  1.877392e+04    3538.984910    3048.110913
#
#             psfMag_i       psfMag_z    fiberMag_u     fiberMag_g  \
# count  199991.000000  199991.000000  1.999910e+05  199991.000000
# mean       18.043495      17.663526  1.084986e+01      19.072693
# std       116.622194     123.735298  4.172116e+03     749.256162
# min    -26566.310827  -24878.828280 -1.864766e+06 -215882.917191
# ...

# %% [markdown]
# ### 상관관계 확인
# * psfMag_u,fiberMag_u, petroMag_u 간에 음의 상관관계

# %%
plt.figure(figsize =(15,10))
sns.heatmap(train_df.corr().applymap(lambda x :round(x,2)),annot = True)

# %% [markdown]
# ## type에 따른 비교

# %%
import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-102-86e89bd44552> in <module>()
# ----> 1 import plotly.express as px
#
# ~\Anaconda3\lib\site-packages\plotly\express\__init__.py in <module>()
#       5 from __future__ import absolute_import
#       6 from plotly import optional_imports
# ----> 7 from ._imshow import imshow
#       8
#       9 pd = optional_imports.get_module("pandas")
#
# ~\Anaconda3\lib\site-packages\plotly\express\_imshow.py in <module>()
#       1 import plotly.graph_objs as go
#       2 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 3 from ._core import apply_default_cascade
#       4 import numpy as np
#       5
#
# ~\Anaconda3\lib\site-packages\plotly\express\_core.py in <module>()
#       4
#       5 from _plotly_utils.basevalidators import ColorscaleValidator
# ----> 6 from .colors import qualitative, sequential
# ...

# %%
sns.countplot(x= 'type',data = train_df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### describe
# type에 따라 u을 제외하고 비슷한 양상을 보임

# %%
train_df[train_df.type == 'QSO'].iloc[:,1:].describe()
# Out:
#             fiberID      psfMag_u      psfMag_g      psfMag_r      psfMag_i  \
# count  49680.000000  4.968000e+04  49680.000000  49680.000000  49680.000000
# mean     475.962540 -8.519955e+01     20.844459     20.562275     20.389592
# std      283.314172  2.382709e+04      1.144866      1.167290      1.188138
# min        1.000000 -5.310802e+06      8.420418      0.814350    -30.711890
# 25%      234.000000  2.080806e+01     20.232979     19.914293     19.725654
# 50%      464.000000  2.166885e+01     21.071196     20.773945     20.604364
# 75%      711.000000  2.244038e+01     21.646985     21.394157     21.236891
# max     1000.000000  3.689395e+02     50.646416     50.849271     61.241476
#
#            psfMag_z    fiberMag_u     fiberMag_g    fiberMag_r    fiberMag_i  \
# count  49680.000000  4.968000e+04   49680.000000  49680.000000  49680.000000
# mean      20.245893 -1.562802e+01      21.771637     20.831491     20.663179
# ...

# %%
train_df[train_df.type == 'GALAXY'].iloc[:,1:].describe()
# Out:
#             fiberID      psfMag_u      psfMag_g      psfMag_r      psfMag_i  \
# count  37347.000000  37347.000000  37347.000000  37347.000000  37347.000000
# mean     320.190671     20.622170     18.448683     18.436685     18.410367
# std      183.815642    182.358486    137.966910     51.096266     40.129426
# min        1.000000 -23314.142046 -19866.754771  -6851.105514  -6027.957170
# 25%      161.000000     20.706658     19.147752     18.310141     17.908379
# 50%      319.000000     21.263317     19.668772     18.802144     18.380594
# 75%      480.000000     21.886297     20.233082     19.382380     18.973773
# max      640.000000  18773.919070    478.440761    923.580805   4835.218639
#
#            psfMag_z    fiberMag_u    fiberMag_g    fiberMag_r    fiberMag_i  \
# count  37347.000000  37347.000000  37347.000000  37347.000000  37347.000000
# mean      17.211240     19.614352     18.563599     18.585088     17.866836
# ...

# %% [markdown]
# ### fiberID
# * fiberID가 type별로 균등분배되어있는 것은 아니다

# %%
#fiberID가 type별로 균등분배되어있는 것은 아니다
pd.pivot_table(index="fiberID",columns = "type",values= 'psfMag_u',aggfunc = 'count',data= train_df).tail()
# Out:
# type     GALAXY   QSO  REDDEN_STD  ROSAT_D  SERENDIPITY_BLUE  \
# fiberID
# 996         NaN  72.0         NaN      NaN               NaN
# 997         NaN  14.0         NaN      NaN               NaN
# 998         NaN  75.0         NaN      NaN               NaN
# 999         NaN  27.0         NaN      NaN               NaN
# 1000        NaN  67.0         NaN      NaN               NaN
#
# type     SERENDIPITY_DISTANT  SERENDIPITY_FIRST  SERENDIPITY_MANUAL  \
# fiberID
# 996                      NaN                NaN                 NaN
# 997                      NaN                NaN                 NaN
# 998                      NaN                NaN                 NaN
# 999                      NaN                NaN                 NaN
# 1000                     NaN                NaN                 NaN
#
# type     SERENDIPITY_RED  SKY  SPECTROPHOTO_STD  STAR_BHB  STAR_BROWN_DWARF  \
# fiberID
# 996                  NaN  NaN               NaN       NaN               NaN
# ...

# %%
#특정 fiberID는 굉장히 적다
train_df.fiberID.value_counts().tail()
# Out:
# 809    11
# 807    11
# 737    10
# 991    10
# 853     9
# Name: fiberID, dtype: int64

# %% [markdown]
# ### psfMag
# 특히 sky는 모든값이 가장 유사한것으로 보임 (표본수가 적기때문으로 추정)
# psfMag_u에부터 z로 가면서 점점 수치가 적어지는 경향을 보임

# %%
def draw_boxplot(selected_col, data, y_value, nrow=2, ncol=3, figsize=(12,12)):
    plt.figure(figsize=figsize)
#     plt.suptitle(title, fontsize=15)
    for i in range(0,len(selected_col)):
        col_name = selected_col[i]
        sample_df = data[(data[col_name] >10)&(data[col_name] <30)]
        plt.subplot(nrow,ncol,i+1)
        g = sns.boxplot(x=y_value, y=selected_col[i], data= sample_df)
        g.set_title(selected_col[i], fontsize=10)
        g.set_ylabel("")
        plt.xticks(rotation=90)
        plt.axhline(sample_df.psfMag_u.median(),c= 'r')
        print(f"{col_name} 제외된 Data수 : {data.shape[0]-sample_df.shape[0]}")
    plt.tight_layout()
    return

# %%
selected_col = train_df.columns.values[2:7]
draw_boxplot(selected_col,train_df,'type')
# Out:
# psfMag_u 제외된 Data수 : 101
# psfMag_g 제외된 Data수 : 69
# psfMag_r 제외된 Data수 : 62
# psfMag_i 제외된 Data수 : 43
# psfMag_z 제외된 Data수 : 57

# %% [markdown]
# ### fiberMag
# psfMag_i와 유사함
# 특히 sky는 모든값이 가장 유사한것으로 보임 (표본수가 적기때문으로 추정)
# psfMag_u에부터 z로 가면서 점점 수치가 적어지는 경향을 보임

# %%
selected_col = train_df.columns.values[7:12]
draw_boxplot(selected_col,train_df,'type')
# Out:
# fiberMag_u 제외된 Data수 : 92
# fiberMag_g 제외된 Data수 : 40
# fiberMag_r 제외된 Data수 : 24
# fiberMag_i 제외된 Data수 : 21
# fiberMag_z 제외된 Data수 : 37

# %% [markdown]
# ### petroMag
# 제외되는 데이터의 양이 많은 것으로 보아 오차가 많이 나는 것으로 추정
# u에부터 z로 가면서 점점 수치가 적어지는 경향을 보임
# 다른 컬럼들에 비해 outliar가 많은편

# %%
selected_col = train_df.columns.values[12:17]
draw_boxplot(selected_col,train_df,'type')
# Out:
# petroMag_u 제외된 Data수 : 853
# petroMag_g 제외된 Data수 : 261
# petroMag_r 제외된 Data수 : 173
# petroMag_i 제외된 Data수 : 156
# petroMag_z 제외된 Data수 : 207

# %%
print(f"10이하 : {train_df[train_df.petroMag_u<10].shape[0]}건, 30이상 : {train_df[train_df.petroMag_u>30].shape[0]}건")
# Out:
# 10이하 : 162건, 30이상 : 691건

# %%
#혹시나해서 30이상이 중위값인가 확인인가 확인
train_df.petroMag_u.describe()
# Out:
# count    199991.000000
# mean         21.837903
# std         789.472333
# min      -24463.431833
# 25%          19.247795
# 50%          20.366848
# 75%          21.797480
# max      298771.019041
# Name: petroMag_u, dtype: float64

# %% [markdown]
# ### modelMag
# 제외되는 데이터의 양이 많은 것으로 보아 오차가 많이 나는 것으로 추정
# psfMag_u에부터 z로 가면서 점점 수치가 적어지는 경향을 보임

# %%
selected_col = train_df.columns.values[17:]
draw_boxplot(selected_col,train_df,'type')
# Out:
# modelMag_u 제외된 Data수 : 64
# modelMag_g 제외된 Data수 : 34
# modelMag_r 제외된 Data수 : 29
# modelMag_i 제외된 Data수 : 26
# modelMag_z 제외된 Data수 : 33

# %% [markdown]
# ### fiberID에 따라서 범위가 안정적이다?
# * fiberID 144에서 기각됨

# %%
train_df[train_df.fiberID == 373].iloc[:,1:].describe()
# Out:
#        fiberID    psfMag_u    psfMag_g    psfMag_r    psfMag_i    psfMag_z  \
# count    270.0  270.000000  270.000000  270.000000  270.000000  270.000000
# mean     373.0   20.800373   19.667739   19.011120   18.516262   18.229767
# std        0.0    2.208738    2.094301    1.786392    1.544931    1.588651
# min      373.0   16.805273   15.760299   15.329556   14.900097   14.299017
# 25%      373.0   19.399585   18.356708   17.764498   17.422577   17.117345
# 50%      373.0   20.541701   19.659617   19.187068   18.697650   18.206673
# 75%      373.0   21.952358   20.807253   20.194823   19.776951   19.408140
# max      373.0   28.807145   31.098415   26.662362   22.304619   24.590185
#
#        fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    20.905343   19.819489   19.174577   18.702036   18.458063   20.352241
# ...

# %%
#fiberID 144에서 기각됨
train_df[train_df.fiberID == 144].iloc[:,1:].describe()
# Out:
#        fiberID      psfMag_u      psfMag_g    psfMag_r    psfMag_i  \
# count    285.0    285.000000    285.000000  285.000000  285.000000
# mean     144.0     86.979260    -16.635824   19.426782   19.047295
# std        0.0   1110.818225    618.381448    1.529139    1.475727
# min      144.0     16.615050 -10419.446631   15.466033   15.433500
# 25%      144.0     19.866247     19.022963   18.394389   17.995190
# 50%      144.0     20.978981     19.964698   19.566312   19.205877
# 75%      144.0     22.324670     21.239226   20.472149   20.101654
# max      144.0  18773.919070     25.264898   23.311095   21.907281
#
#            psfMag_z   fiberMag_u   fiberMag_g  fiberMag_r  fiberMag_i  \
# count    285.000000   285.000000   285.000000  285.000000  285.000000
# mean     -20.317222    -8.733996    15.966394   19.666769   19.282048
# std      659.914423   508.133413    72.360155    1.547567    1.496378
# min   -11121.835456 -8556.853083 -1200.986368   15.795164   15.775519
# ...

# %% [markdown]
# ### fiberID당 다른 변수들이 차이가 있을까?

# %%
#1000개 모두를 확인하기엔 다소 어려움이 있기에 350개 이상이 있는 fiberID를 대상으로 함
count_df = train_df.fiberID.value_counts()
sample = count_df[count_df>350].index.values

s_train_df = train_df[train_df.fiberID.apply(lambda x: x in sample)]
# Out:
# array([624, 122, 618, 350,  14, 316, 620, 626,  28,  38, 360, 434, 338,
#        612, 622, 308, 274, 606, 322], dtype=int64)

# %%
s_train_df = train_df[train_df.fiberID.apply(lambda x: x in sample)]

# %% [markdown]
# #### psfMag
# 큰차이없다

# %%
selected_col = train_df.columns.values[2:7]
draw_boxplot(selected_col,s_train_df,'fiberID')
# Out:
# psfMag_u 제외된 Data수 : 1
# psfMag_g 제외된 Data수 : 1
# psfMag_r 제외된 Data수 : 0
# psfMag_i 제외된 Data수 : 1
# psfMag_z 제외된 Data수 : 0

# %% [markdown]
# #### fiberMag
# 큰차이없다

# %%
selected_col = train_df.columns.values[7:12]
draw_boxplot(selected_col,s_train_df,'fiberID')
# Out:
# fiberMag_u 제외된 Data수 : 1
# fiberMag_g 제외된 Data수 : 0
# fiberMag_r 제외된 Data수 : 0
# fiberMag_i 제외된 Data수 : 0
# fiberMag_z 제외된 Data수 : 1

# %% [markdown]
# #### petroMag
# 큰차이없다

# %%
selected_col = train_df.columns.values[12:17]
draw_boxplot(selected_col,s_train_df,'fiberID')
# Out:
# petroMag_u 제외된 Data수 : 27
# petroMag_g 제외된 Data수 : 9
# petroMag_r 제외된 Data수 : 4
# petroMag_i 제외된 Data수 : 5
# petroMag_z 제외된 Data수 : 5

# %% [markdown]
# #### modelMag
# 큰차이없다

# %%
selected_col = train_df.columns.values[17:]
draw_boxplot(selected_col,s_train_df,'fiberID')
# Out:
# modelMag_u 제외된 Data수 : 0
# modelMag_g 제외된 Data수 : 0
# modelMag_r 제외된 Data수 : 0
# modelMag_i 제외된 Data수 : 0
# modelMag_z 제외된 Data수 : 0

# %% [markdown]
# ## 두변수들간 scatter

# %%
train_df.head()
# Out:
#               type  fiberID   psfMag_u   psfMag_g   psfMag_r   psfMag_i  \
# id
# 0              QSO      601  23.198224  21.431953  21.314148  21.176553
# 1              QSO      788  21.431355  20.708104  20.678850  20.703420
# 2              QSO      427  17.851451  16.727898  16.679677  16.694640
# 3              QSO      864  20.789900  20.040371  19.926909  19.843840
# 4   STAR_RED_DWARF      612  26.454969  23.058767  21.471406  19.504961
#
#      psfMag_z  fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  \
# id
# 0   21.171444   22.581309   21.644453   21.657571   21.387653   21.572827
# 1   20.473229   21.868797   21.029773   20.967054   20.937731   21.063646
# 2   16.641788   18.171890   17.033098   16.999682   17.095999   17.076449
# 3   19.463270   21.039030   20.317165   20.217898   20.073852   19.794505
# 4   18.389096   25.700632   23.629122   21.742750   19.861718   18.810375
#
#     petroMag_u  petroMag_g  petroMag_r  petroMag_i  petroMag_z  modelMag_u  \
# ...

# %%
s_train_df = train_df[(train_df.psfMag_u>10)&(train_df.psfMag_u<30)]
s_train_df = s_train_df[(s_train_df.psfMag_g>10)&(s_train_df.psfMag_g<30)]

# %%
#모든 class를 한번에 보기는 어렵다
sns.scatterplot(x= 'psfMag_u', y= 'psfMag_g',hue = 'type',data = s_train_df)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %%
top5 = ['QSO', 'GALAXY', 'SERENDIPITY_BLUE', 'SPECTROPHOTO_STD', 'REDDEN_STD']

ss_train_df = s_train_df[s_train_df.type.apply(lambda x: x in top5)]

# %%
#5개의 클래스만 추려서 확인
#QSO와 GALAXY글 제외하고 추세가 대략있는것처럼 보인다 둘을 제외한다
sns.scatterplot(x= 'psfMag_u', y= 'psfMag_g',hue = 'type',data = ss_train_df)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %%
top5in3 = ['SPECTROPHOTO_STD', 'REDDEN_STD']
ss_train_df = s_train_df[s_train_df.type.apply(lambda x: x in top5in3)]

# %%
#['SPECTROPHOTO_STD', 'REDDEN_STD'] 2개의 클래스는 구분이 될것으로 추정
sns.scatterplot(x= 'psfMag_u', y= 'psfMag_g',hue = 'type',data = ss_train_df)
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")

# %% [markdown]
# ### PCA로 각 변수묶음별로 확인해볼필요는 있을듯

# %% [markdown]
# # Baseline_MLP
# * 결과 : 0.3957622486
# * keras로 작성하는게 더 용이해서 keras로 Sequential model구축하고 baseline과 동일한 layer 유지

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

import sklearn
from sklearn.preprocessing import StandardScaler
# Out:
# C:\Users\starl\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:493: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\starl\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:494: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\starl\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:495: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
unique_labels = train_df['type'].unique()
label_dict = {val: i for i, val in enumerate(unique_labels)}
i2lb = {v:k for k, v in label_dict.items()}

# %%
scaler = StandardScaler()
labels = train_df['type']
train_df = train_df.drop(columns=['fiberID', 'type']) # fiberID는 1000개의 categorical feature이며, 이 커널에서는 무시합니다.

# %%
_mat = scaler.fit_transform(train_df)
train_df = pd.DataFrame(_mat, columns=train_df.columns, index=train_df.index)

# %%
train_x = train_df
train_y = labels.replace(label_dict)

# %%
import keras 
from keras import models
from keras import layers
from keras import optimizers

# %%
optimizer = optimizers.Adam(lr = 0.0003)

# %%
model = models.Sequential()
model.add(layers.Dense(256*4, activation='elu',input_dim = (train_x.shape[1])))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(256*4, activation='elu'))
model.add(layers.Dense(256*3, activation='elu'))
model.add(layers.Dropout(0.15))
model.add(layers.Dense(256*3, activation='elu'))
model.add(layers.Dense(256*2, activation='elu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(256*2, activation='elu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(256*2, activation='elu'))
model.add(layers.Dropout(0.15))
model.add(layers.Dense(256*1, activation='elu'))
model.add(layers.Dense(256*1, activation='elu'))
model.add(layers.Dropout(0.15))
model.add(layers.Dense(128, activation='elu'))
model.add(layers.Dropout(0.1))
model.add(layers.Dense(64, activation='elu'))
model.add(layers.Dense(32, activation='elu'))
model.add(layers.Dense(19, activation='softmax'))

# %%
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_x.values,
          train_y.values,
          batch_size=256*3,
          validation_split=0.1,
          epochs=200)
# Out:
# Train on 179991 samples, validate on 20000 samples
# Epoch 1/200
#  39936/179991 [=====>........................] - ETA: 1:02 - loss: 1.6698 - acc: 0.5090
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-abab22a2933f> in <module>()
#       3           batch_size=256*3,
#       4           validation_split=0.1,
# ----> 5           epochs=200)
#
# ~\Anaconda3\lib\site-packages\keras\models.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#     963                               initial_epoch=initial_epoch,
#     964                               steps_per_epoch=steps_per_epoch,
# --> 965                               validation_steps=validation_steps)
#     966
#     967     def evaluate(self, x=None, y=None,
#
# ...

# %%
test_ids = test_df.index.values
test_df = test_df.drop(columns=['fiberID'])
test_df = pd.DataFrame(scaler.transform(test_df), columns=test_df.columns, index=test_df.index)

# %%
pred_mat = model.predict(test_df)

# %%
submission = pd.DataFrame(pred_mat, index=test_df.index)
submission = submission.rename(columns=i2lb)
# submission = pd.concat([test_ids, submission], axis=1)
submission = submission[sample_submission_df.columns]
submission.to_csv("submission.csv")

# %% [markdown]
# # Baseline_RF
# * 결과 : 0.5469542991

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\starl\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
train = pd.read_csv(path +'train.csv', index_col=0)
test = pd.read_csv(path +'test.csv', index_col=0)
sample_submission = pd.read_csv(path +'sample_submission.csv', index_col=0)

# %%
column_number = {}
for i, column in enumerate(sample_submission.columns):
    column_number[column] = i
    
def to_number(x, dic):
    return dic[x]

train['type_num'] = train['type'].apply(lambda x: to_number(x, column_number))

# %%
train_x = train.drop(columns=['type', 'type_num'], axis=1)
train_y = train['type_num']
test_x = test

# %%
forest = RandomForestClassifier(n_estimators=100, n_jobs=-1)
forest.fit(train_x, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
forest.

# %%
pi_df = pd.DataFrame(forest.feature_importances_, index= train_x.columns,columns= ['importance']).sort_values('importance',ascending = False)
pi_df.head()
# Out:
#             importance
# psfMag_u      0.069199
# modelMag_z    0.067230
# psfMag_g      0.064627
# fiberMag_u    0.059807
# modelMag_g    0.057361

# %%
y_pred = forest.predict_proba(test_x)

# %%
submission = pd.DataFrame(data=y_pred, columns=sample_submission.columns, index=sample_submission.index)
submission.to_csv('submission.csv', index=True)
