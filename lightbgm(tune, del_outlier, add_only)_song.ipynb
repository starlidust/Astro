# %% [markdown]
# # Tune_lgb
# * 제출결과 :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import log_loss
import lightgbm as lgb

# %%
path = "./data/" 
train_df = pd.read_csv(path+'train.csv',index_col=0)
test_df = pd.read_csv(path+'test.csv',index_col=0)
sample_submission_df = pd.read_csv(path+'sample_submission.csv',index_col=0)
pd.options.display.max_columns = 30

# %% [markdown]
# ## 전처리
#  - 이상치 확인 및 처리

# %%
train_df.describe()
# Out:
#              fiberID      psfMag_u       psfMag_g       psfMag_r  \
# count  199991.000000  1.999910e+05  199991.000000  199991.000000
# mean      360.830152 -6.750146e+00      18.675373      18.401235
# std       225.305890  1.187678e+04     155.423024     127.128078
# min         1.000000 -5.310802e+06  -40022.466071  -27184.795793
# 25%       174.000000  1.965259e+01      18.701180      18.048572
# 50%       349.000000  2.087136e+01      19.904235      19.454492
# 75%       526.000000  2.216043e+01      21.150297      20.515936
# max      1000.000000  1.877392e+04    3538.984910    3048.110913
#
#             psfMag_i       psfMag_z    fiberMag_u     fiberMag_g  \
# count  199991.000000  199991.000000  1.999910e+05  199991.000000
# mean       18.043495      17.663526  1.084986e+01      19.072693
# std       116.622194     123.735298  4.172116e+03     749.256162
# min    -26566.310827  -24878.828280 -1.864766e+06 -215882.917191
# 25%        17.747663      17.425523  1.994040e+01      18.902851
# 50%        19.043895      18.611799  2.104910e+01      20.069038
# 75%        20.073528      19.883760  2.233754e+01      21.385830
# max      4835.218639    9823.740407  4.870154e+03  248077.513380
#
#           fiberMag_r     fiberMag_i     fiberMag_z     petroMag_u  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       19.134483      18.183331      18.000882      21.837903
# std        90.049058     122.378972     145.862346     789.472333
# min    -21802.656144  -20208.516262  -26505.602101  -24463.431833
# 25%        18.259352      17.903615      17.606148      19.247795
# 50%        19.631419      19.188763      18.710967      20.366848
# 75%        20.773911      20.331419      20.133179      21.797480
# max     12084.735440    8059.638535   18358.921741  298771.019041
#
#           petroMag_g     petroMag_r     petroMag_i     petroMag_z  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       18.454136      18.481525      17.686617      17.699207
# std       154.376277      97.240448     145.730872     142.691880
# min    -25958.752324  -23948.588523  -40438.184078  -30070.729379
# 25%        18.113933      17.479794      17.050294      16.804705
# 50%        19.586559      19.182789      18.693370      18.174592
# 75%        21.004397      20.457491      20.019112      19.807652
# max     12139.815877    7003.136546    9772.190537   17403.789263
#
#           modelMag_u     modelMag_g     modelMag_r     modelMag_i  \
# count  199991.000000  199991.000000  199991.000000  199991.000000
# mean       20.110991      18.544375      18.181544      17.692395
# std       122.299062     161.728183     133.984475     131.183416
# min    -26236.578659  -36902.402336  -36439.638493  -38969.416822
# 25%        19.266214      18.076120      17.423425      16.977671
# 50%        20.406840      19.547674      19.143156      18.641756
# 75%        21.992898      20.962386      20.408140      19.968846
# max     14488.251976   10582.058590   12237.951703    4062.499371
#
#           modelMag_z
# count  199991.000000
# mean       17.189281
# std       133.685138
# min    -26050.710196
# 25%        16.705774
# 50%        18.100997
# 75%        19.819554
# max      7420.534172

# %%
def del_outlier(data, min=0, max=60):
    up_idx_t=()
    dw_idx_t=()
    train_light = data.iloc[:,2:]
    for i in range(len(train_light.columns)):
        col = train_light.columns[i]
        up_idx_t+=tuple(data[data[col]>max].index)
        dw_idx_t+=tuple(data[data[col]<min].index)
    del_idx = set(up_idx_t+dw_idx_t)
    
    data[~data.index.isin(del_idx)].describe()
    
    return data

# %%
train_df = del_outlier(train_df, min=-60, max=60)

# %%
train_df.columns
# Out:
# Index(['type', 'fiberID', 'psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'],
#       dtype='object')

# %% [markdown]
# ## DATA Setting

# %%
column_number = {}
number_columns = {}
for i, column in enumerate(sample_submission_df.columns):
    column_number[column] = i
    number_columns[i] = column
    
    
def to_number(x, dic):
    return dic[x]

train_df['type_num'] = train_df['type'].apply(lambda x: to_number(x, column_number))

# %%
def add_minus_feature_all(data,test = False):
    from itertools import combinations
    n = 0
    for count in range(5,21,5):
        s = 2
        if test == True :
            s = 1
        selected = data.columns[s:].values[n:count]
        mag = str.split(selected[0],'_')[0]
        for combi in list(combinations(selected,2)):
            name_1st = str.split(combi[0],'_')[1]
            name_2nd = str.split(combi[1],'_')[1]
            data[mag+"_"+name_1st+"-"+name_2nd] = data[combi[0]]-data[combi[1]]
        n=count
    return data

# %%
def add_minus_feature(data,test = False):
    '''
    근접변수에 대해서만 컬럼생성 ex) 'fiberMag_u-g', 'fiberMag_g-r', 'fiberMag_r-i', 'fiberMag_i-z'
    각 mag에서 가장 높은값의 filter를 받아오는 "~~mag_MAX"생성
    결과 38개로 증가 
    '''
    from itertools import combinations
    n = 0
    m = 0
    for count in range(5,21,5):
        s = 2
        if test == True :
            s = 1
        selected = data.columns[s:].values[n:count]
        mag = str.split(selected[0],'_')[0]
#         data[mag+"_MAX"] = data[selected].apply(lambda x : str.split(np.argmax(x),'_')[1],axis = 1)
        for i in range(0,len(selected)):        
            if i>0: 
                name_1st = str.split(m,'_')[1]
                name_2nd = str.split(selected[i],'_')[1]
                data[mag+"_"+name_1st+"-"+name_2nd] = data[m]-data[selected[i]]
            m = selected[i]    
        n=count
    return data

# %%
train_df = add_minus_feature(train_df)
test_df = add_minus_feature(test_df,True)

# %%
# train_df.drop(columns=['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'], inplace=True)

# test_df.drop(columns=['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i',
#        'psfMag_z', 'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i',
#        'fiberMag_z', 'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i',
#        'petroMag_z', 'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i',
#        'modelMag_z'], inplace=True)

# %%
train_X = train_df.drop(columns=['type', 'type_num', 'fiberID'], axis=1)
train_y = train_df['type_num']
test_X = test_df.drop(columns=['fiberID'], axis=1)

# %%
train_X.head()
# Out:
#      psfMag_u   psfMag_g   psfMag_r   psfMag_i   psfMag_z  fiberMag_u  \
# id
# 0   23.198224  21.431953  21.314148  21.176553  21.171444   22.581309
# 1   21.431355  20.708104  20.678850  20.703420  20.473229   21.868797
# 2   17.851451  16.727898  16.679677  16.694640  16.641788   18.171890
# 3   20.789900  20.040371  19.926909  19.843840  19.463270   21.039030
# 4   26.454969  23.058767  21.471406  19.504961  18.389096   25.700632
#
#     fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  petroMag_g  \
# id
# 0    21.644453   21.657571   21.387653   21.572827   22.504317   21.431636
# 1    21.029773   20.967054   20.937731   21.063646   21.360701   20.778968
# 2    17.033098   16.999682   17.095999   17.076449   17.867253   16.738784
# 3    20.317165   20.217898   20.073852   19.794505   20.433907   19.993727
# 4    23.629122   21.742750   19.861718   18.810375   25.859229   22.426929
#
#     petroMag_r  petroMag_i  petroMag_z  ...  psfMag_g-r  psfMag_r-i  \
# id                                      ...
# 0    21.478312   21.145409   20.422446  ...    0.117805    0.137595
# 1    20.889705   20.639812   20.646660  ...    0.029254   -0.024570
# 2    16.688874   16.744210   16.808006  ...    0.048221   -0.014963
# 3    19.985531   19.750917   19.455117  ...    0.113462    0.083069
# 4    21.673551   19.610012   18.376141  ...    1.587361    1.966445
#
#     psfMag_i-z  fiberMag_u-g  fiberMag_g-r  fiberMag_r-i  fiberMag_i-z  \
# id
# 0     0.005109      0.936856     -0.013118      0.269918     -0.185174
# 1     0.230191      0.839024      0.062718      0.029324     -0.125915
# 2     0.052852      1.138792      0.033416     -0.096317      0.019550
# 3     0.380569      0.721865      0.099267      0.144046      0.279347
# 4     1.115864      2.071510      1.886372      1.881032      1.051343
#
#     petroMag_u-g  petroMag_g-r  petroMag_r-i  petroMag_i-z  modelMag_u-g  \
# id
# 0       1.072682     -0.046676      0.332902      0.722964      1.283708
# 1       0.581734     -0.110737      0.249893     -0.006847      0.734428
# 2       1.128468      0.049910     -0.055336     -0.063796      1.120628
# 3       0.440180      0.008197      0.234614      0.295800      0.769012
# 4       3.432300      0.753377      2.063539      1.233871      1.729059
#
#     modelMag_g-r  modelMag_r-i  modelMag_i-z
# id
# 0       0.101347      0.343582     -0.126735
# 1       0.004602      0.060537      0.181074
# 2       0.056186     -0.018929     -0.028751
# 3       0.111901      0.131685      0.205258
# 4       1.672651      1.988012      1.111675
#
# [5 rows x 36 columns]

# %%
train_X.columns
# Out:
# Index(['psfMag_u', 'psfMag_g', 'psfMag_r', 'psfMag_i', 'psfMag_z',
#        'fiberMag_u', 'fiberMag_g', 'fiberMag_r', 'fiberMag_i', 'fiberMag_z',
#        'petroMag_u', 'petroMag_g', 'petroMag_r', 'petroMag_i', 'petroMag_z',
#        'modelMag_u', 'modelMag_g', 'modelMag_r', 'modelMag_i', 'modelMag_z',
#        'psfMag_u-g', 'psfMag_g-r', 'psfMag_r-i', 'psfMag_i-z', 'fiberMag_u-g',
#        'fiberMag_g-r', 'fiberMag_r-i', 'fiberMag_i-z', 'petroMag_u-g',
#        'petroMag_g-r', 'petroMag_r-i', 'petroMag_i-z', 'modelMag_u-g',
#        'modelMag_g-r', 'modelMag_r-i', 'modelMag_i-z'],
#       dtype='object')

# %%
# ## u-g, g-r, r-i, i-z 만 남기는게 좋지 않을까????
# train_X.drop(['psfMag_u-r','psfMag_u-i','psfMag_u-z','psfMag_g-i','psfMag_g-z','psfMag_r-z',
#              'fiberMag_u-r','fiberMag_u-i','fiberMag_u-z','fiberMag_g-i','fiberMag_g-z','fiberMag_r-z',
#              'petroMag_u-r','petroMag_u-i','petroMag_u-z','petroMag_g-i','petroMag_g-z','petroMag_r-z',
#              'modelMag_u-r','modelMag_u-i','modelMag_u-z','modelMag_g-i','modelMag_g-z','modelMag_r-z'] ,axis=1, inplace=True)

# test_X.drop(['psfMag_u-r','psfMag_u-i','psfMag_u-z','psfMag_g-i','psfMag_g-z','psfMag_r-z',
#              'fiberMag_u-r','fiberMag_u-i','fiberMag_u-z','fiberMag_g-i','fiberMag_g-z','fiberMag_r-z',
#              'petroMag_u-r','petroMag_u-i','petroMag_u-z','petroMag_g-i','petroMag_g-z','petroMag_r-z',
#              'modelMag_u-r','modelMag_u-i','modelMag_u-z','modelMag_g-i','modelMag_g-z','modelMag_r-z'] ,axis=1, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(train_X, train_y, test_size=0.3, random_state=59,stratify = train_y)

# %%
# train_ds = lgb.Dataset(X_train, label = y_train, categorical_feature=['fiberID'])
# test_ds = lgb.Dataset(X_test, label = y_test, categorical_feature=['fiberID']) 
train_ds = lgb.Dataset(X_train, label = y_train)
test_ds = lgb.Dataset(X_test, label = y_test)

# %%
#1번
params = {
    'boosting_type': 'dart',
    'objective': 'multiclass',
    'num_class': train_y.nunique(),
    'metric': {'multi_logloss','multi_logloss'},
    'num_leaves': 25,
    'learning_rate': 0.009,
    'max_depth' : 11,
    'random_state' : 59
}

# %%
# #2번
# params = {
#     'boosting_type': 'dart',
#     'objective': 'multiclass',
#     'num_class': train_y.nunique(),
#     'metric': {'multi_logloss','multi_logloss'},
#     'num_leaves': 25,
#     'learning_rate': 0.05,
#     'max_depth' : 9,
#     'random_state' : 1029
# }

# %% [markdown]
# ## Modeling

# %%
evaluation_results = {}
lgmb_model = lgb.train(params, train_ds,num_boost_round= 6000, 
                       valid_sets = [train_ds,test_ds], valid_names=['Train', 'Test'],
                       evals_result=evaluation_results,
                       verbose_eval=10, early_stopping_rounds=50)
# Out:
# [10]	Train's multi_logloss: 2.15068	Test's multi_logloss: 2.15554
# [20]	Train's multi_logloss: 2.13656	Test's multi_logloss: 2.14123
# [30]	Train's multi_logloss: 1.98016	Test's multi_logloss: 1.98582
# [40]	Train's multi_logloss: 1.92229	Test's multi_logloss: 1.92825
# [50]	Train's multi_logloss: 1.90044	Test's multi_logloss: 1.90635
# [60]	Train's multi_logloss: 1.85133	Test's multi_logloss: 1.85754
# [70]	Train's multi_logloss: 1.80293	Test's multi_logloss: 1.8096
# [80]	Train's multi_logloss: 1.7301	Test's multi_logloss: 1.73739
# [90]	Train's multi_logloss: 1.66514	Test's multi_logloss: 1.67306
# [100]	Train's multi_logloss: 1.67555	Test's multi_logloss: 1.68334
# [110]	Train's multi_logloss: 1.70959	Test's multi_logloss: 1.71727
# [120]	Train's multi_logloss: 1.62477	Test's multi_logloss: 1.63321
# [130]	Train's multi_logloss: 1.71318	Test's multi_logloss: 1.72091
# [140]	Train's multi_logloss: 1.68049	Test's multi_logloss: 1.68866
# [150]	Train's multi_logloss: 1.5794	Test's multi_logloss: 1.58839
# [160]	Train's multi_logloss: 1.52845	Test's multi_logloss: 1.5379
# [170]	Train's multi_logloss: 1.51593	Test's multi_logloss: 1.52562
# [180]	Train's multi_logloss: 1.54026	Test's multi_logloss: 1.5498
# [190]	Train's multi_logloss: 1.47622	Test's multi_logloss: 1.48636
# [200]	Train's multi_logloss: 1.44829	Test's multi_logloss: 1.45883
# [210]	Train's multi_logloss: 1.42594	Test's multi_logloss: 1.43664
# [220]	Train's multi_logloss: 1.3952	Test's multi_logloss: 1.40624
# [230]	Train's multi_logloss: 1.37662	Test's multi_logloss: 1.38782
# [240]	Train's multi_logloss: 1.37468	Test's multi_logloss: 1.38588
# [250]	Train's multi_logloss: 1.29313	Test's multi_logloss: 1.30517
# [260]	Train's multi_logloss: 1.29688	Test's multi_logloss: 1.30893
# [270]	Train's multi_logloss: 1.26741	Test's multi_logloss: 1.27973
# [280]	Train's multi_logloss: 1.28584	Test's multi_logloss: 1.29799
# [290]	Train's multi_logloss: 1.255	Test's multi_logloss: 1.26748
# [300]	Train's multi_logloss: 1.22752	Test's multi_logloss: 1.24025
# [310]	Train's multi_logloss: 1.1882	Test's multi_logloss: 1.20132
# [320]	Train's multi_logloss: 1.2066	Test's multi_logloss: 1.21956
# [330]	Train's multi_logloss: 1.18283	Test's multi_logloss: 1.19605
# [340]	Train's multi_logloss: 1.17028	Test's multi_logloss: 1.18364
# [350]	Train's multi_logloss: 1.14533	Test's multi_logloss: 1.15898
# [360]	Train's multi_logloss: 1.11019	Test's multi_logloss: 1.12424
# [370]	Train's multi_logloss: 1.10317	Test's multi_logloss: 1.11736
# [380]	Train's multi_logloss: 1.11017	Test's multi_logloss: 1.12437
# [390]	Train's multi_logloss: 1.06699	Test's multi_logloss: 1.08173
# [400]	Train's multi_logloss: 1.0775	Test's multi_logloss: 1.09213
# [410]	Train's multi_logloss: 1.06721	Test's multi_logloss: 1.08198
# [420]	Train's multi_logloss: 1.06758	Test's multi_logloss: 1.08237
# [430]	Train's multi_logloss: 1.02672	Test's multi_logloss: 1.04204
# [440]	Train's multi_logloss: 1.00677	Test's multi_logloss: 1.02239
# [450]	Train's multi_logloss: 0.989144	Test's multi_logloss: 1.00506
# [460]	Train's multi_logloss: 0.991387	Test's multi_logloss: 1.00732
# [470]	Train's multi_logloss: 0.973526	Test's multi_logloss: 0.989754
# [480]	Train's multi_logloss: 0.966083	Test's multi_logloss: 0.982458
# [490]	Train's multi_logloss: 0.966935	Test's multi_logloss: 0.983313
# [500]	Train's multi_logloss: 0.952434	Test's multi_logloss: 0.969042
# [510]	Train's multi_logloss: 0.945971	Test's multi_logloss: 0.962726
# [520]	Train's multi_logloss: 0.931138	Test's multi_logloss: 0.948148
# [530]	Train's multi_logloss: 0.899789	Test's multi_logloss: 0.917286
# [540]	Train's multi_logloss: 0.908241	Test's multi_logloss: 0.925621
# [550]	Train's multi_logloss: 0.908489	Test's multi_logloss: 0.925881
# [560]	Train's multi_logloss: 0.908551	Test's multi_logloss: 0.925961
# [570]	Train's multi_logloss: 0.915343	Test's multi_logloss: 0.932675
# [580]	Train's multi_logloss: 0.917589	Test's multi_logloss: 0.934962
# [590]	Train's multi_logloss: 0.910563	Test's multi_logloss: 0.928064
# [600]	Train's multi_logloss: 0.895699	Test's multi_logloss: 0.913454
# [610]	Train's multi_logloss: 0.879459	Test's multi_logloss: 0.897489
# [620]	Train's multi_logloss: 0.850384	Test's multi_logloss: 0.868881
# [630]	Train's multi_logloss: 0.863229	Test's multi_logloss: 0.881541
# [640]	Train's multi_logloss: 0.841828	Test's multi_logloss: 0.860491
# [650]	Train's multi_logloss: 0.834707	Test's multi_logloss: 0.853502
# [660]	Train's multi_logloss: 0.839948	Test's multi_logloss: 0.858678
# [670]	Train's multi_logloss: 0.857421	Test's multi_logloss: 0.875894
# [680]	Train's multi_logloss: 0.855402	Test's multi_logloss: 0.873923
# [690]	Train's multi_logloss: 0.833092	Test's multi_logloss: 0.851971
# [700]	Train's multi_logloss: 0.812977	Test's multi_logloss: 0.832178
# [710]	Train's multi_logloss: 0.78758	Test's multi_logloss: 0.807222
# [720]	Train's multi_logloss: 0.797061	Test's multi_logloss: 0.816543
# [730]	Train's multi_logloss: 0.790611	Test's multi_logloss: 0.810243
# [740]	Train's multi_logloss: 0.794044	Test's multi_logloss: 0.813638
# [750]	Train's multi_logloss: 0.786198	Test's multi_logloss: 0.805945
# [760]	Train's multi_logloss: 0.784274	Test's multi_logloss: 0.804049
# [770]	Train's multi_logloss: 0.777083	Test's multi_logloss: 0.796992
# [780]	Train's multi_logloss: 0.779696	Test's multi_logloss: 0.799562
# [790]	Train's multi_logloss: 0.772587	Test's multi_logloss: 0.792577
# [800]	Train's multi_logloss: 0.775531	Test's multi_logloss: 0.79548
# [810]	Train's multi_logloss: 0.768277	Test's multi_logloss: 0.788358
# [820]	Train's multi_logloss: 0.76035	Test's multi_logloss: 0.78058
# [830]	Train's multi_logloss: 0.74296	Test's multi_logloss: 0.763508
# [840]	Train's multi_logloss: 0.740093	Test's multi_logloss: 0.760713
# [850]	Train's multi_logloss: 0.732817	Test's multi_logloss: 0.753612
# [860]	Train's multi_logloss: 0.735224	Test's multi_logloss: 0.755999
# [870]	Train's multi_logloss: 0.732208	Test's multi_logloss: 0.753064
# [880]	Train's multi_logloss: 0.729586	Test's multi_logloss: 0.750515
# [890]	Train's multi_logloss: 0.723348	Test's multi_logloss: 0.74443
# [900]	Train's multi_logloss: 0.730462	Test's multi_logloss: 0.751438
# [910]	Train's multi_logloss: 0.715473	Test's multi_logloss: 0.736788
# [920]	Train's multi_logloss: 0.722552	Test's multi_logloss: 0.743756
# [930]	Train's multi_logloss: 0.728019	Test's multi_logloss: 0.74913
# [940]	Train's multi_logloss: 0.725125	Test's multi_logloss: 0.746306
# [950]	Train's multi_logloss: 0.730952	Test's multi_logloss: 0.752023
# [960]	Train's multi_logloss: 0.731625	Test's multi_logloss: 0.752685
# [970]	Train's multi_logloss: 0.714868	Test's multi_logloss: 0.736252
# [980]	Train's multi_logloss: 0.707139	Test's multi_logloss: 0.728685
# [990]	Train's multi_logloss: 0.695904	Test's multi_logloss: 0.717708
# [1000]	Train's multi_logloss: 0.692612	Test's multi_logloss: 0.714514
# [1010]	Train's multi_logloss: 0.68178	Test's multi_logloss: 0.703949
# [1020]	Train's multi_logloss: 0.671082	Test's multi_logloss: 0.693503
# [1030]	Train's multi_logloss: 0.657031	Test's multi_logloss: 0.679779
# [1040]	Train's multi_logloss: 0.644062	Test's multi_logloss: 0.667133
# [1050]	Train's multi_logloss: 0.635192	Test's multi_logloss: 0.65849
# [1060]	Train's multi_logloss: 0.640651	Test's multi_logloss: 0.66386
# [1070]	Train's multi_logloss: 0.631614	Test's multi_logloss: 0.655074
# [1080]	Train's multi_logloss: 0.61992	Test's multi_logloss: 0.64371
# [1090]	Train's multi_logloss: 0.615065	Test's multi_logloss: 0.639004
# [1100]	Train's multi_logloss: 0.604005	Test's multi_logloss: 0.628266
# [1110]	Train's multi_logloss: 0.602075	Test's multi_logloss: 0.626402
# [1120]	Train's multi_logloss: 0.604041	Test's multi_logloss: 0.628338
# [1130]	Train's multi_logloss: 0.596813	Test's multi_logloss: 0.621308
# [1140]	Train's multi_logloss: 0.590243	Test's multi_logloss: 0.614956
# [1150]	Train's multi_logloss: 0.580029	Test's multi_logloss: 0.605016
# [1160]	Train's multi_logloss: 0.56784	Test's multi_logloss: 0.593193
# [1170]	Train's multi_logloss: 0.559182	Test's multi_logloss: 0.584842
# [1180]	Train's multi_logloss: 0.554052	Test's multi_logloss: 0.579936
# [1190]	Train's multi_logloss: 0.555235	Test's multi_logloss: 0.581112
# [1200]	Train's multi_logloss: 0.549507	Test's multi_logloss: 0.575602
# [1210]	Train's multi_logloss: 0.546478	Test's multi_logloss: 0.572735
# [1220]	Train's multi_logloss: 0.547321	Test's multi_logloss: 0.573581
# [1230]	Train's multi_logloss: 0.539374	Test's multi_logloss: 0.565952
# [1240]	Train's multi_logloss: 0.536047	Test's multi_logloss: 0.562784
# [1250]	Train's multi_logloss: 0.528596	Test's multi_logloss: 0.555653
# [1260]	Train's multi_logloss: 0.527766	Test's multi_logloss: 0.554896
# [1270]	Train's multi_logloss: 0.528991	Test's multi_logloss: 0.556099
# [1280]	Train's multi_logloss: 0.528818	Test's multi_logloss: 0.555992
# [1290]	Train's multi_logloss: 0.523711	Test's multi_logloss: 0.551125
# [1300]	Train's multi_logloss: 0.516449	Test's multi_logloss: 0.544189
# [1310]	Train's multi_logloss: 0.515266	Test's multi_logloss: 0.543093
# [1320]	Train's multi_logloss: 0.512198	Test's multi_logloss: 0.540186
# [1330]	Train's multi_logloss: 0.509857	Test's multi_logloss: 0.537985
# [1340]	Train's multi_logloss: 0.50947	Test's multi_logloss: 0.537647
# [1350]	Train's multi_logloss: 0.508607	Test's multi_logloss: 0.536857
# [1360]	Train's multi_logloss: 0.509373	Test's multi_logloss: 0.537633
# [1370]	Train's multi_logloss: 0.506374	Test's multi_logloss: 0.534785
# [1380]	Train's multi_logloss: 0.509313	Test's multi_logloss: 0.537647
# [1390]	Train's multi_logloss: 0.500881	Test's multi_logloss: 0.529618
# [1400]	Train's multi_logloss: 0.49607	Test's multi_logloss: 0.525057
# [1410]	Train's multi_logloss: 0.493333	Test's multi_logloss: 0.522482
# [1420]	Train's multi_logloss: 0.492763	Test's multi_logloss: 0.521966
# [1430]	Train's multi_logloss: 0.488434	Test's multi_logloss: 0.517892
# [1440]	Train's multi_logloss: 0.48586	Test's multi_logloss: 0.5155
# [1450]	Train's multi_logloss: 0.486268	Test's multi_logloss: 0.515924
# [1460]	Train's multi_logloss: 0.483535	Test's multi_logloss: 0.513363
# [1470]	Train's multi_logloss: 0.483652	Test's multi_logloss: 0.513507
# [1480]	Train's multi_logloss: 0.479752	Test's multi_logloss: 0.509842
# [1490]	Train's multi_logloss: 0.478726	Test's multi_logloss: 0.508916
# [1500]	Train's multi_logloss: 0.47909	Test's multi_logloss: 0.5093
# [1510]	Train's multi_logloss: 0.479473	Test's multi_logloss: 0.509709
# [1520]	Train's multi_logloss: 0.476738	Test's multi_logloss: 0.507163
# [1530]	Train's multi_logloss: 0.468542	Test's multi_logloss: 0.499453
# [1540]	Train's multi_logloss: 0.466163	Test's multi_logloss: 0.497246
# [1550]	Train's multi_logloss: 0.465246	Test's multi_logloss: 0.496422
# [1560]	Train's multi_logloss: 0.46477	Test's multi_logloss: 0.496016
# [1570]	Train's multi_logloss: 0.462912	Test's multi_logloss: 0.494314
# [1580]	Train's multi_logloss: 0.464784	Test's multi_logloss: 0.496126
# [1590]	Train's multi_logloss: 0.463937	Test's multi_logloss: 0.495373
# [1600]	Train's multi_logloss: 0.462911	Test's multi_logloss: 0.494453
# [1610]	Train's multi_logloss: 0.462097	Test's multi_logloss: 0.493743
# [1620]	Train's multi_logloss: 0.458464	Test's multi_logloss: 0.490365
# [1630]	Train's multi_logloss: 0.45129	Test's multi_logloss: 0.483687
# [1640]	Train's multi_logloss: 0.449148	Test's multi_logloss: 0.481717
# [1650]	Train's multi_logloss: 0.449527	Test's multi_logloss: 0.482105
# [1660]	Train's multi_logloss: 0.445082	Test's multi_logloss: 0.477971
# [1670]	Train's multi_logloss: 0.442916	Test's multi_logloss: 0.475985
# [1680]	Train's multi_logloss: 0.439988	Test's multi_logloss: 0.473296
# [1690]	Train's multi_logloss: 0.439301	Test's multi_logloss: 0.472703
# [1700]	Train's multi_logloss: 0.438265	Test's multi_logloss: 0.471779
# [1710]	Train's multi_logloss: 0.437899	Test's multi_logloss: 0.471496
# [1720]	Train's multi_logloss: 0.434008	Test's multi_logloss: 0.467942
# [1730]	Train's multi_logloss: 0.431404	Test's multi_logloss: 0.465584
# [1740]	Train's multi_logloss: 0.428847	Test's multi_logloss: 0.463275
# [1750]	Train's multi_logloss: 0.428875	Test's multi_logloss: 0.463339
# [1760]	Train's multi_logloss: 0.425385	Test's multi_logloss: 0.460182
# [1770]	Train's multi_logloss: 0.424913	Test's multi_logloss: 0.459811
# [1780]	Train's multi_logloss: 0.424209	Test's multi_logloss: 0.459202
# [1790]	Train's multi_logloss: 0.421692	Test's multi_logloss: 0.456951
# [1800]	Train's multi_logloss: 0.421147	Test's multi_logloss: 0.456507
# [1810]	Train's multi_logloss: 0.41866	Test's multi_logloss: 0.454264
# [1820]	Train's multi_logloss: 0.416213	Test's multi_logloss: 0.452067
# [1830]	Train's multi_logloss: 0.415484	Test's multi_logloss: 0.451435
# [1840]	Train's multi_logloss: 0.415626	Test's multi_logloss: 0.451615
# [1850]	Train's multi_logloss: 0.414141	Test's multi_logloss: 0.450309
# [1860]	Train's multi_logloss: 0.411645	Test's multi_logloss: 0.448066
# [1870]	Train's multi_logloss: 0.41102	Test's multi_logloss: 0.44755
# [1880]	Train's multi_logloss: 0.408789	Test's multi_logloss: 0.445576
# [1890]	Train's multi_logloss: 0.407376	Test's multi_logloss: 0.444338
# [1900]	Train's multi_logloss: 0.407611	Test's multi_logloss: 0.444595
# [1910]	Train's multi_logloss: 0.40932	Test's multi_logloss: 0.446196
# [1920]	Train's multi_logloss: 0.408137	Test's multi_logloss: 0.445175
# [1930]	Train's multi_logloss: 0.407007	Test's multi_logloss: 0.444229
# [1940]	Train's multi_logloss: 0.404759	Test's multi_logloss: 0.442234
# [1950]	Train's multi_logloss: 0.402736	Test's multi_logloss: 0.44045
# [1960]	Train's multi_logloss: 0.401932	Test's multi_logloss: 0.439765
# [1970]	Train's multi_logloss: 0.400662	Test's multi_logloss: 0.438664
# [1980]	Train's multi_logloss: 0.39958	Test's multi_logloss: 0.437725
# [1990]	Train's multi_logloss: 0.39967	Test's multi_logloss: 0.437847
# [2000]	Train's multi_logloss: 0.39708	Test's multi_logloss: 0.435544
# [2010]	Train's multi_logloss: 0.395316	Test's multi_logloss: 0.434009
# [2020]	Train's multi_logloss: 0.393272	Test's multi_logloss: 0.432241
# [2030]	Train's multi_logloss: 0.390809	Test's multi_logloss: 0.430093
# [2040]	Train's multi_logloss: 0.389024	Test's multi_logloss: 0.428557
# [2050]	Train's multi_logloss: 0.386039	Test's multi_logloss: 0.425966
# [2060]	Train's multi_logloss: 0.386254	Test's multi_logloss: 0.426202
# [2070]	Train's multi_logloss: 0.385201	Test's multi_logloss: 0.425334
# [2080]	Train's multi_logloss: 0.384219	Test's multi_logloss: 0.424518
# [2090]	Train's multi_logloss: 0.383211	Test's multi_logloss: 0.42369
# [2100]	Train's multi_logloss: 0.38101	Test's multi_logloss: 0.421819
# [2110]	Train's multi_logloss: 0.379424	Test's multi_logloss: 0.42048
# [2120]	Train's multi_logloss: 0.378461	Test's multi_logloss: 0.419697
# [2130]	Train's multi_logloss: 0.376967	Test's multi_logloss: 0.418478
# [2140]	Train's multi_logloss: 0.374918	Test's multi_logloss: 0.416789
# [2150]	Train's multi_logloss: 0.373948	Test's multi_logloss: 0.416011
# [2160]	Train's multi_logloss: 0.372548	Test's multi_logloss: 0.414875
# [2170]	Train's multi_logloss: 0.371513	Test's multi_logloss: 0.414045
# [2180]	Train's multi_logloss: 0.3723	Test's multi_logloss: 0.414773
# [2190]	Train's multi_logloss: 0.372932	Test's multi_logloss: 0.415363
# [2200]	Train's multi_logloss: 0.370635	Test's multi_logloss: 0.41346
# [2210]	Train's multi_logloss: 0.370277	Test's multi_logloss: 0.413218
# [2220]	Train's multi_logloss: 0.368431	Test's multi_logloss: 0.411707
# [2230]	Train's multi_logloss: 0.368056	Test's multi_logloss: 0.411445
# [2240]	Train's multi_logloss: 0.367682	Test's multi_logloss: 0.411179
# [2250]	Train's multi_logloss: 0.365952	Test's multi_logloss: 0.409787
# [2260]	Train's multi_logloss: 0.366417	Test's multi_logloss: 0.410234
# [2270]	Train's multi_logloss: 0.366432	Test's multi_logloss: 0.410292
# [2280]	Train's multi_logloss: 0.363858	Test's multi_logloss: 0.408185
# [2290]	Train's multi_logloss: 0.363689	Test's multi_logloss: 0.408098
# [2300]	Train's multi_logloss: 0.363863	Test's multi_logloss: 0.408302
# [2310]	Train's multi_logloss: 0.363593	Test's multi_logloss: 0.408125
# [2320]	Train's multi_logloss: 0.363337	Test's multi_logloss: 0.407968
# [2330]	Train's multi_logloss: 0.36217	Test's multi_logloss: 0.40706
# [2340]	Train's multi_logloss: 0.360216	Test's multi_logloss: 0.405474
# [2350]	Train's multi_logloss: 0.358996	Test's multi_logloss: 0.404509
# [2360]	Train's multi_logloss: 0.358228	Test's multi_logloss: 0.403938
# [2370]	Train's multi_logloss: 0.357544	Test's multi_logloss: 0.403434
# [2380]	Train's multi_logloss: 0.356792	Test's multi_logloss: 0.402867
# [2390]	Train's multi_logloss: 0.356895	Test's multi_logloss: 0.403007
# [2400]	Train's multi_logloss: 0.355036	Test's multi_logloss: 0.401547
# [2410]	Train's multi_logloss: 0.354032	Test's multi_logloss: 0.400791
# [2420]	Train's multi_logloss: 0.352247	Test's multi_logloss: 0.399418
# [2430]	Train's multi_logloss: 0.35229	Test's multi_logloss: 0.399499
# [2440]	Train's multi_logloss: 0.352017	Test's multi_logloss: 0.399332
# [2450]	Train's multi_logloss: 0.35175	Test's multi_logloss: 0.399166
# [2460]	Train's multi_logloss: 0.350424	Test's multi_logloss: 0.39814
# [2470]	Train's multi_logloss: 0.35055	Test's multi_logloss: 0.398295
# [2480]	Train's multi_logloss: 0.349886	Test's multi_logloss: 0.397814
# [2490]	Train's multi_logloss: 0.349271	Test's multi_logloss: 0.397374
# [2500]	Train's multi_logloss: 0.34833	Test's multi_logloss: 0.396668
# [2510]	Train's multi_logloss: 0.348026	Test's multi_logloss: 0.396479
# [2520]	Train's multi_logloss: 0.347754	Test's multi_logloss: 0.396311
# [2530]	Train's multi_logloss: 0.347161	Test's multi_logloss: 0.3959
# [2540]	Train's multi_logloss: 0.347291	Test's multi_logloss: 0.396061
# [2550]	Train's multi_logloss: 0.346337	Test's multi_logloss: 0.395372
# [2560]	Train's multi_logloss: 0.346412	Test's multi_logloss: 0.395485
# [2570]	Train's multi_logloss: 0.344856	Test's multi_logloss: 0.394336
# [2580]	Train's multi_logloss: 0.344502	Test's multi_logloss: 0.394122
# [2590]	Train's multi_logloss: 0.343877	Test's multi_logloss: 0.393715
# [2600]	Train's multi_logloss: 0.343254	Test's multi_logloss: 0.393289
# [2610]	Train's multi_logloss: 0.344396	Test's multi_logloss: 0.394237
# [2620]	Train's multi_logloss: 0.343576	Test's multi_logloss: 0.393657
# [2630]	Train's multi_logloss: 0.342613	Test's multi_logloss: 0.392952
# [2640]	Train's multi_logloss: 0.34142	Test's multi_logloss: 0.392104
# [2650]	Train's multi_logloss: 0.339984	Test's multi_logloss: 0.391065
# [2660]	Train's multi_logloss: 0.339774	Test's multi_logloss: 0.390963
# [2670]	Train's multi_logloss: 0.339265	Test's multi_logloss: 0.390637
# [2680]	Train's multi_logloss: 0.339041	Test's multi_logloss: 0.390536
# [2690]	Train's multi_logloss: 0.337928	Test's multi_logloss: 0.389761
# [2700]	Train's multi_logloss: 0.337588	Test's multi_logloss: 0.38957
# [2710]	Train's multi_logloss: 0.337064	Test's multi_logloss: 0.389251
# [2720]	Train's multi_logloss: 0.336278	Test's multi_logloss: 0.388727
# [2730]	Train's multi_logloss: 0.336009	Test's multi_logloss: 0.388604
# [2740]	Train's multi_logloss: 0.335294	Test's multi_logloss: 0.388148
# [2750]	Train's multi_logloss: 0.33499	Test's multi_logloss: 0.387985
# [2760]	Train's multi_logloss: 0.334771	Test's multi_logloss: 0.387891
# [2770]	Train's multi_logloss: 0.333742	Test's multi_logloss: 0.387211
# [2780]	Train's multi_logloss: 0.332739	Test's multi_logloss: 0.386536
# [2790]	Train's multi_logloss: 0.332496	Test's multi_logloss: 0.386422
# [2800]	Train's multi_logloss: 0.331236	Test's multi_logloss: 0.385586
# [2810]	Train's multi_logloss: 0.331074	Test's multi_logloss: 0.385528
# [2820]	Train's multi_logloss: 0.33084	Test's multi_logloss: 0.385418
# [2830]	Train's multi_logloss: 0.330622	Test's multi_logloss: 0.385316
# [2840]	Train's multi_logloss: 0.32964	Test's multi_logloss: 0.384703
# [2850]	Train's multi_logloss: 0.329421	Test's multi_logloss: 0.384608
# [2860]	Train's multi_logloss: 0.329218	Test's multi_logloss: 0.384536
# [2870]	Train's multi_logloss: 0.328789	Test's multi_logloss: 0.384307
# [2880]	Train's multi_logloss: 0.328138	Test's multi_logloss: 0.383917
# [2890]	Train's multi_logloss: 0.327878	Test's multi_logloss: 0.383792
# [2900]	Train's multi_logloss: 0.327968	Test's multi_logloss: 0.383923
# [2910]	Train's multi_logloss: 0.32707	Test's multi_logloss: 0.38338
# [2920]	Train's multi_logloss: 0.326824	Test's multi_logloss: 0.383269
# [2930]	Train's multi_logloss: 0.326359	Test's multi_logloss: 0.383016
# [2940]	Train's multi_logloss: 0.325644	Test's multi_logloss: 0.382581
# [2950]	Train's multi_logloss: 0.325005	Test's multi_logloss: 0.382212
# [2960]	Train's multi_logloss: 0.32521	Test's multi_logloss: 0.382408
# [2970]	Train's multi_logloss: 0.324552	Test's multi_logloss: 0.382032
# [2980]	Train's multi_logloss: 0.323461	Test's multi_logloss: 0.381347
# [2990]	Train's multi_logloss: 0.324018	Test's multi_logloss: 0.381782
# [3000]	Train's multi_logloss: 0.323166	Test's multi_logloss: 0.381274
# [3010]	Train's multi_logloss: 0.322738	Test's multi_logloss: 0.381042
# [3020]	Train's multi_logloss: 0.322112	Test's multi_logloss: 0.380691
# [3030]	Train's multi_logloss: 0.321696	Test's multi_logloss: 0.380479
# [3040]	Train's multi_logloss: 0.321253	Test's multi_logloss: 0.380234
# [3050]	Train's multi_logloss: 0.320849	Test's multi_logloss: 0.380028
# [3060]	Train's multi_logloss: 0.31983	Test's multi_logloss: 0.379437
# [3070]	Train's multi_logloss: 0.319235	Test's multi_logloss: 0.379117
# [3080]	Train's multi_logloss: 0.318679	Test's multi_logloss: 0.378824
# [3090]	Train's multi_logloss: 0.318328	Test's multi_logloss: 0.378659
# [3100]	Train's multi_logloss: 0.317598	Test's multi_logloss: 0.378251
# [3110]	Train's multi_logloss: 0.317195	Test's multi_logloss: 0.378053
# [3120]	Train's multi_logloss: 0.316841	Test's multi_logloss: 0.377884
# [3130]	Train's multi_logloss: 0.316319	Test's multi_logloss: 0.377616
# [3140]	Train's multi_logloss: 0.315807	Test's multi_logloss: 0.377359
# [3150]	Train's multi_logloss: 0.31549	Test's multi_logloss: 0.377228
# [3160]	Train's multi_logloss: 0.315151	Test's multi_logloss: 0.37708
# [3170]	Train's multi_logloss: 0.31478	Test's multi_logloss: 0.376907
# [3180]	Train's multi_logloss: 0.314605	Test's multi_logloss: 0.37686
# [3190]	Train's multi_logloss: 0.314091	Test's multi_logloss: 0.376609
# [3200]	Train's multi_logloss: 0.313905	Test's multi_logloss: 0.376554
# [3210]	Train's multi_logloss: 0.313761	Test's multi_logloss: 0.376524
# [3220]	Train's multi_logloss: 0.313053	Test's multi_logloss: 0.376149
# [3230]	Train's multi_logloss: 0.312741	Test's multi_logloss: 0.376012
# [3240]	Train's multi_logloss: 0.312533	Test's multi_logloss: 0.375927
# [3250]	Train's multi_logloss: 0.312704	Test's multi_logloss: 0.376081
# [3260]	Train's multi_logloss: 0.312175	Test's multi_logloss: 0.37581
# [3270]	Train's multi_logloss: 0.311832	Test's multi_logloss: 0.375655
# [3280]	Train's multi_logloss: 0.311121	Test's multi_logloss: 0.375289
# [3290]	Train's multi_logloss: 0.310435	Test's multi_logloss: 0.374949
# [3300]	Train's multi_logloss: 0.310276	Test's multi_logloss: 0.374918
# [3310]	Train's multi_logloss: 0.309287	Test's multi_logloss: 0.374394
# [3320]	Train's multi_logloss: 0.309097	Test's multi_logloss: 0.374337
# [3330]	Train's multi_logloss: 0.308605	Test's multi_logloss: 0.374099
# [3340]	Train's multi_logloss: 0.308296	Test's multi_logloss: 0.373976
# [3350]	Train's multi_logloss: 0.307661	Test's multi_logloss: 0.373678
# [3360]	Train's multi_logloss: 0.30779	Test's multi_logloss: 0.373799
# [3370]	Train's multi_logloss: 0.307645	Test's multi_logloss: 0.373766
# [3380]	Train's multi_logloss: 0.307186	Test's multi_logloss: 0.373553
# [3390]	Train's multi_logloss: 0.30736	Test's multi_logloss: 0.373696
# [3400]	Train's multi_logloss: 0.306756	Test's multi_logloss: 0.373403
# [3410]	Train's multi_logloss: 0.306321	Test's multi_logloss: 0.373208
# [3420]	Train's multi_logloss: 0.30617	Test's multi_logloss: 0.373172
# [3430]	Train's multi_logloss: 0.30572	Test's multi_logloss: 0.372969
# [3440]	Train's multi_logloss: 0.305534	Test's multi_logloss: 0.37292
# [3450]	Train's multi_logloss: 0.305556	Test's multi_logloss: 0.372982
# [3460]	Train's multi_logloss: 0.305576	Test's multi_logloss: 0.373037
# [3470]	Train's multi_logloss: 0.305262	Test's multi_logloss: 0.372902
# [3480]	Train's multi_logloss: 0.305097	Test's multi_logloss: 0.372851
# [3490]	Train's multi_logloss: 0.304803	Test's multi_logloss: 0.372731
# [3500]	Train's multi_logloss: 0.304402	Test's multi_logloss: 0.372557
# [3510]	Train's multi_logloss: 0.304254	Test's multi_logloss: 0.372511
# [3520]	Train's multi_logloss: 0.303948	Test's multi_logloss: 0.372386
# [3530]	Train's multi_logloss: 0.303671	Test's multi_logloss: 0.372288
# [3540]	Train's multi_logloss: 0.303522	Test's multi_logloss: 0.372254
# [3550]	Train's multi_logloss: 0.30376	Test's multi_logloss: 0.372427
# [3560]	Train's multi_logloss: 0.303738	Test's multi_logloss: 0.372466
# [3570]	Train's multi_logloss: 0.303312	Test's multi_logloss: 0.372283
# [3580]	Train's multi_logloss: 0.303216	Test's multi_logloss: 0.372269
# [3590]	Train's multi_logloss: 0.302786	Test's multi_logloss: 0.372061
# [3600]	Train's multi_logloss: 0.302607	Test's multi_logloss: 0.372001
# [3610]	Train's multi_logloss: 0.302602	Test's multi_logloss: 0.372041
# [3620]	Train's multi_logloss: 0.302381	Test's multi_logloss: 0.371951
# [3630]	Train's multi_logloss: 0.302078	Test's multi_logloss: 0.371812
# [3640]	Train's multi_logloss: 0.301937	Test's multi_logloss: 0.371782
# [3650]	Train's multi_logloss: 0.301751	Test's multi_logloss: 0.371722
# [3660]	Train's multi_logloss: 0.301347	Test's multi_logloss: 0.371533
# [3670]	Train's multi_logloss: 0.300909	Test's multi_logloss: 0.371328
# [3680]	Train's multi_logloss: 0.30021	Test's multi_logloss: 0.371002
# [3690]	Train's multi_logloss: 0.29995	Test's multi_logloss: 0.370912
# [3700]	Train's multi_logloss: 0.299769	Test's multi_logloss: 0.370858
# [3710]	Train's multi_logloss: 0.299324	Test's multi_logloss: 0.370669
# [3720]	Train's multi_logloss: 0.299164	Test's multi_logloss: 0.370625
# [3730]	Train's multi_logloss: 0.298859	Test's multi_logloss: 0.370512
# [3740]	Train's multi_logloss: 0.298828	Test's multi_logloss: 0.370539
# [3750]	Train's multi_logloss: 0.298662	Test's multi_logloss: 0.370493
# [3760]	Train's multi_logloss: 0.298377	Test's multi_logloss: 0.370388
# [3770]	Train's multi_logloss: 0.29798	Test's multi_logloss: 0.370212
# [3780]	Train's multi_logloss: 0.297413	Test's multi_logloss: 0.369973
# [3790]	Train's multi_logloss: 0.296994	Test's multi_logloss: 0.369803
# [3800]	Train's multi_logloss: 0.296857	Test's multi_logloss: 0.369784
# [3810]	Train's multi_logloss: 0.296351	Test's multi_logloss: 0.369582
# [3820]	Train's multi_logloss: 0.295823	Test's multi_logloss: 0.369374
# [3830]	Train's multi_logloss: 0.295316	Test's multi_logloss: 0.369186
# [3840]	Train's multi_logloss: 0.295062	Test's multi_logloss: 0.369121
# [3850]	Train's multi_logloss: 0.294435	Test's multi_logloss: 0.36888
# [3860]	Train's multi_logloss: 0.293928	Test's multi_logloss: 0.368694
# [3870]	Train's multi_logloss: 0.293558	Test's multi_logloss: 0.36858
# [3880]	Train's multi_logloss: 0.293182	Test's multi_logloss: 0.36845
# [3890]	Train's multi_logloss: 0.292576	Test's multi_logloss: 0.368229
# [3900]	Train's multi_logloss: 0.292444	Test's multi_logloss: 0.368209
# [3910]	Train's multi_logloss: 0.291963	Test's multi_logloss: 0.368049
# [3920]	Train's multi_logloss: 0.291466	Test's multi_logloss: 0.36788
# [3930]	Train's multi_logloss: 0.291311	Test's multi_logloss: 0.367855
# [3940]	Train's multi_logloss: 0.290981	Test's multi_logloss: 0.367753
# [3950]	Train's multi_logloss: 0.290862	Test's multi_logloss: 0.367741
# [3960]	Train's multi_logloss: 0.290264	Test's multi_logloss: 0.367535
# [3970]	Train's multi_logloss: 0.290053	Test's multi_logloss: 0.367489
# [3980]	Train's multi_logloss: 0.290077	Test's multi_logloss: 0.367538
# [3990]	Train's multi_logloss: 0.289846	Test's multi_logloss: 0.36747
# [4000]	Train's multi_logloss: 0.289482	Test's multi_logloss: 0.367351
# [4010]	Train's multi_logloss: 0.289043	Test's multi_logloss: 0.367211
# [4020]	Train's multi_logloss: 0.288942	Test's multi_logloss: 0.367193
# [4030]	Train's multi_logloss: 0.288927	Test's multi_logloss: 0.367219
# [4040]	Train's multi_logloss: 0.288594	Test's multi_logloss: 0.367111
# [4050]	Train's multi_logloss: 0.288268	Test's multi_logloss: 0.36701
# [4060]	Train's multi_logloss: 0.288355	Test's multi_logloss: 0.367089
# [4070]	Train's multi_logloss: 0.288028	Test's multi_logloss: 0.366975
# [4080]	Train's multi_logloss: 0.288005	Test's multi_logloss: 0.367004
# [4090]	Train's multi_logloss: 0.287897	Test's multi_logloss: 0.366991
# [4100]	Train's multi_logloss: 0.287803	Test's multi_logloss: 0.366997
# [4110]	Train's multi_logloss: 0.287676	Test's multi_logloss: 0.366989
# [4120]	Train's multi_logloss: 0.287468	Test's multi_logloss: 0.36694
# [4130]	Train's multi_logloss: 0.287196	Test's multi_logloss: 0.36687
# [4140]	Train's multi_logloss: 0.287178	Test's multi_logloss: 0.366899
# [4150]	Train's multi_logloss: 0.286824	Test's multi_logloss: 0.366794
# [4160]	Train's multi_logloss: 0.286811	Test's multi_logloss: 0.366823
# [4170]	Train's multi_logloss: 0.286488	Test's multi_logloss: 0.36672
# [4180]	Train's multi_logloss: 0.286311	Test's multi_logloss: 0.366686
# [4190]	Train's multi_logloss: 0.286203	Test's multi_logloss: 0.366676
# [4200]	Train's multi_logloss: 0.285764	Test's multi_logloss: 0.366519
# [4210]	Train's multi_logloss: 0.285417	Test's multi_logloss: 0.366411
# [4220]	Train's multi_logloss: 0.285226	Test's multi_logloss: 0.366368
# [4230]	Train's multi_logloss: 0.284988	Test's multi_logloss: 0.366307
# [4240]	Train's multi_logloss: 0.284848	Test's multi_logloss: 0.366278
# [4250]	Train's multi_logloss: 0.28487	Test's multi_logloss: 0.366328
# [4260]	Train's multi_logloss: 0.284426	Test's multi_logloss: 0.366184
# [4270]	Train's multi_logloss: 0.284328	Test's multi_logloss: 0.366185
# [4280]	Train's multi_logloss: 0.284	Test's multi_logloss: 0.366087
# [4290]	Train's multi_logloss: 0.283548	Test's multi_logloss: 0.365935
# [4300]	Train's multi_logloss: 0.283219	Test's multi_logloss: 0.365832
# [4310]	Train's multi_logloss: 0.282896	Test's multi_logloss: 0.365737
# [4320]	Train's multi_logloss: 0.282672	Test's multi_logloss: 0.36569
# [4330]	Train's multi_logloss: 0.282456	Test's multi_logloss: 0.365641
# [4340]	Train's multi_logloss: 0.282232	Test's multi_logloss: 0.365599
# [4350]	Train's multi_logloss: 0.282245	Test's multi_logloss: 0.365631
# [4360]	Train's multi_logloss: 0.281938	Test's multi_logloss: 0.36555
# [4370]	Train's multi_logloss: 0.281719	Test's multi_logloss: 0.365502
# [4380]	Train's multi_logloss: 0.281487	Test's multi_logloss: 0.36545
# [4390]	Train's multi_logloss: 0.28131	Test's multi_logloss: 0.365426
# [4400]	Train's multi_logloss: 0.28079	Test's multi_logloss: 0.365268
# [4410]	Train's multi_logloss: 0.28047	Test's multi_logloss: 0.365185
# [4420]	Train's multi_logloss: 0.280359	Test's multi_logloss: 0.365181
# [4430]	Train's multi_logloss: 0.280048	Test's multi_logloss: 0.365088
# [4440]	Train's multi_logloss: 0.279636	Test's multi_logloss: 0.364976
# [4450]	Train's multi_logloss: 0.279335	Test's multi_logloss: 0.364919
# [4460]	Train's multi_logloss: 0.279228	Test's multi_logloss: 0.364911
# [4470]	Train's multi_logloss: 0.279011	Test's multi_logloss: 0.364865
# [4480]	Train's multi_logloss: 0.279007	Test's multi_logloss: 0.364891
# [4490]	Train's multi_logloss: 0.278694	Test's multi_logloss: 0.364825
# [4500]	Train's multi_logloss: 0.278465	Test's multi_logloss: 0.36478
# [4510]	Train's multi_logloss: 0.278254	Test's multi_logloss: 0.364733
# [4520]	Train's multi_logloss: 0.278064	Test's multi_logloss: 0.364694
# [4530]	Train's multi_logloss: 0.278054	Test's multi_logloss: 0.364726
# [4540]	Train's multi_logloss: 0.277574	Test's multi_logloss: 0.364606
# [4550]	Train's multi_logloss: 0.277409	Test's multi_logloss: 0.364584
# [4560]	Train's multi_logloss: 0.277106	Test's multi_logloss: 0.36451
# [4570]	Train's multi_logloss: 0.276994	Test's multi_logloss: 0.364509
# [4580]	Train's multi_logloss: 0.276894	Test's multi_logloss: 0.364502
# [4590]	Train's multi_logloss: 0.276511	Test's multi_logloss: 0.364399
# [4600]	Train's multi_logloss: 0.276412	Test's multi_logloss: 0.364398
# [4610]	Train's multi_logloss: 0.276047	Test's multi_logloss: 0.364308
# [4620]	Train's multi_logloss: 0.275651	Test's multi_logloss: 0.364221
# [4630]	Train's multi_logloss: 0.275521	Test's multi_logloss: 0.364216
# [4640]	Train's multi_logloss: 0.275145	Test's multi_logloss: 0.364119
# [4650]	Train's multi_logloss: 0.274956	Test's multi_logloss: 0.364099
# [4660]	Train's multi_logloss: 0.274754	Test's multi_logloss: 0.364072
# [4670]	Train's multi_logloss: 0.274655	Test's multi_logloss: 0.36407
# [4680]	Train's multi_logloss: 0.27449	Test's multi_logloss: 0.364066
# [4690]	Train's multi_logloss: 0.274113	Test's multi_logloss: 0.363982
# [4700]	Train's multi_logloss: 0.273724	Test's multi_logloss: 0.363886
# [4710]	Train's multi_logloss: 0.273731	Test's multi_logloss: 0.363922
# [4720]	Train's multi_logloss: 0.273374	Test's multi_logloss: 0.36385
# [4730]	Train's multi_logloss: 0.273087	Test's multi_logloss: 0.363795
# [4740]	Train's multi_logloss: 0.273058	Test's multi_logloss: 0.363817
# [4750]	Train's multi_logloss: 0.273043	Test's multi_logloss: 0.36385
# [4760]	Train's multi_logloss: 0.272782	Test's multi_logloss: 0.363803
# [4770]	Train's multi_logloss: 0.272687	Test's multi_logloss: 0.363817
# [4780]	Train's multi_logloss: 0.272322	Test's multi_logloss: 0.363752
# [4790]	Train's multi_logloss: 0.272242	Test's multi_logloss: 0.363762
# [4800]	Train's multi_logloss: 0.271875	Test's multi_logloss: 0.363692
# [4810]	Train's multi_logloss: 0.271677	Test's multi_logloss: 0.363655
# [4820]	Train's multi_logloss: 0.271731	Test's multi_logloss: 0.3637
# [4830]	Train's multi_logloss: 0.271623	Test's multi_logloss: 0.363704
# [4840]	Train's multi_logloss: 0.271328	Test's multi_logloss: 0.363647
# [4850]	Train's multi_logloss: 0.271392	Test's multi_logloss: 0.363696
# [4860]	Train's multi_logloss: 0.271216	Test's multi_logloss: 0.363689
# [4870]	Train's multi_logloss: 0.270864	Test's multi_logloss: 0.36362
# [4880]	Train's multi_logloss: 0.270586	Test's multi_logloss: 0.363567
# [4890]	Train's multi_logloss: 0.270305	Test's multi_logloss: 0.363513
# [4900]	Train's multi_logloss: 0.270014	Test's multi_logloss: 0.363456
# [4910]	Train's multi_logloss: 0.269882	Test's multi_logloss: 0.363443
# [4920]	Train's multi_logloss: 0.269953	Test's multi_logloss: 0.363493
# [4930]	Train's multi_logloss: 0.269736	Test's multi_logloss: 0.36346
# [4940]	Train's multi_logloss: 0.269634	Test's multi_logloss: 0.363467
# [4950]	Train's multi_logloss: 0.26965	Test's multi_logloss: 0.363514
# [4960]	Train's multi_logloss: 0.269114	Test's multi_logloss: 0.363394
# [4970]	Train's multi_logloss: 0.268816	Test's multi_logloss: 0.363338
# [4980]	Train's multi_logloss: 0.268543	Test's multi_logloss: 0.363283
# [4990]	Train's multi_logloss: 0.26844	Test's multi_logloss: 0.363285
# [5000]	Train's multi_logloss: 0.268178	Test's multi_logloss: 0.363234
# [5010]	Train's multi_logloss: 0.268233	Test's multi_logloss: 0.363282
# [5020]	Train's multi_logloss: 0.268035	Test's multi_logloss: 0.363253
# [5030]	Train's multi_logloss: 0.267681	Test's multi_logloss: 0.363178
# [5040]	Train's multi_logloss: 0.267651	Test's multi_logloss: 0.363193
# [5050]	Train's multi_logloss: 0.26722	Test's multi_logloss: 0.363105
# [5060]	Train's multi_logloss: 0.266945	Test's multi_logloss: 0.363058
# [5070]	Train's multi_logloss: 0.266775	Test's multi_logloss: 0.363032
# [5080]	Train's multi_logloss: 0.266594	Test's multi_logloss: 0.363013
# [5090]	Train's multi_logloss: 0.266404	Test's multi_logloss: 0.362997
# [5100]	Train's multi_logloss: 0.266306	Test's multi_logloss: 0.363003
# [5110]	Train's multi_logloss: 0.266229	Test's multi_logloss: 0.363022
# [5120]	Train's multi_logloss: 0.266078	Test's multi_logloss: 0.363008
# [5130]	Train's multi_logloss: 0.265957	Test's multi_logloss: 0.363013
# [5140]	Train's multi_logloss: 0.265795	Test's multi_logloss: 0.363002
# [5150]	Train's multi_logloss: 0.265636	Test's multi_logloss: 0.363002
# [5160]	Train's multi_logloss: 0.265692	Test's multi_logloss: 0.363049
# [5170]	Train's multi_logloss: 0.265525	Test's multi_logloss: 0.363036
# [5180]	Train's multi_logloss: 0.265021	Test's multi_logloss: 0.362929
# [5190]	Train's multi_logloss: 0.264897	Test's multi_logloss: 0.362922
# [5200]	Train's multi_logloss: 0.264732	Test's multi_logloss: 0.362897
# [5210]	Train's multi_logloss: 0.264662	Test's multi_logloss: 0.36291
# [5220]	Train's multi_logloss: 0.264566	Test's multi_logloss: 0.362912
# [5230]	Train's multi_logloss: 0.2644	Test's multi_logloss: 0.362885
# [5240]	Train's multi_logloss: 0.264291	Test's multi_logloss: 0.362883
# [5250]	Train's multi_logloss: 0.264287	Test's multi_logloss: 0.362905
# [5260]	Train's multi_logloss: 0.264024	Test's multi_logloss: 0.362863
# [5270]	Train's multi_logloss: 0.263593	Test's multi_logloss: 0.362775
# [5280]	Train's multi_logloss: 0.263253	Test's multi_logloss: 0.362721
# [5290]	Train's multi_logloss: 0.262991	Test's multi_logloss: 0.362683
# [5300]	Train's multi_logloss: 0.262659	Test's multi_logloss: 0.362616
# [5310]	Train's multi_logloss: 0.262563	Test's multi_logloss: 0.362612
# [5320]	Train's multi_logloss: 0.262638	Test's multi_logloss: 0.362655
# [5330]	Train's multi_logloss: 0.262298	Test's multi_logloss: 0.362599
# [5340]	Train's multi_logloss: 0.26215	Test's multi_logloss: 0.362593
# [5350]	Train's multi_logloss: 0.26205	Test's multi_logloss: 0.362593
# [5360]	Train's multi_logloss: 0.261882	Test's multi_logloss: 0.362575
# [5370]	Train's multi_logloss: 0.261961	Test's multi_logloss: 0.362632
# [5380]	Train's multi_logloss: 0.261797	Test's multi_logloss: 0.362618
# [5390]	Train's multi_logloss: 0.261539	Test's multi_logloss: 0.362573
# [5400]	Train's multi_logloss: 0.261642	Test's multi_logloss: 0.36262
# [5410]	Train's multi_logloss: 0.261621	Test's multi_logloss: 0.362641
# [5420]	Train's multi_logloss: 0.261367	Test's multi_logloss: 0.362612
# [5430]	Train's multi_logloss: 0.261264	Test's multi_logloss: 0.362608
# [5440]	Train's multi_logloss: 0.261168	Test's multi_logloss: 0.362612
# [5450]	Train's multi_logloss: 0.261073	Test's multi_logloss: 0.362613
# [5460]	Train's multi_logloss: 0.260918	Test's multi_logloss: 0.362603
# [5470]	Train's multi_logloss: 0.260866	Test's multi_logloss: 0.362622
# [5480]	Train's multi_logloss: 0.260747	Test's multi_logloss: 0.362615
# [5490]	Train's multi_logloss: 0.260704	Test's multi_logloss: 0.362626
# [5500]	Train's multi_logloss: 0.260465	Test's multi_logloss: 0.362596
# [5510]	Train's multi_logloss: 0.260209	Test's multi_logloss: 0.36256
# [5520]	Train's multi_logloss: 0.25994	Test's multi_logloss: 0.362516
# [5530]	Train's multi_logloss: 0.259986	Test's multi_logloss: 0.362554
# [5540]	Train's multi_logloss: 0.259743	Test's multi_logloss: 0.362526
# [5550]	Train's multi_logloss: 0.259713	Test's multi_logloss: 0.362548
# [5560]	Train's multi_logloss: 0.259614	Test's multi_logloss: 0.362552
# [5570]	Train's multi_logloss: 0.259441	Test's multi_logloss: 0.362536
# [5580]	Train's multi_logloss: 0.259408	Test's multi_logloss: 0.362554
# [5590]	Train's multi_logloss: 0.25924	Test's multi_logloss: 0.362544
# [5600]	Train's multi_logloss: 0.258934	Test's multi_logloss: 0.362497
# [5610]	Train's multi_logloss: 0.258846	Test's multi_logloss: 0.362501
# [5620]	Train's multi_logloss: 0.258754	Test's multi_logloss: 0.362502
# [5630]	Train's multi_logloss: 0.258716	Test's multi_logloss: 0.362518
# [5640]	Train's multi_logloss: 0.258546	Test's multi_logloss: 0.362496
# [5650]	Train's multi_logloss: 0.258217	Test's multi_logloss: 0.36244
# [5660]	Train's multi_logloss: 0.25797	Test's multi_logloss: 0.362408
# [5670]	Train's multi_logloss: 0.257858	Test's multi_logloss: 0.362414
# [5680]	Train's multi_logloss: 0.257764	Test's multi_logloss: 0.362405
# [5690]	Train's multi_logloss: 0.257499	Test's multi_logloss: 0.362364
# [5700]	Train's multi_logloss: 0.25746	Test's multi_logloss: 0.362381
# [5710]	Train's multi_logloss: 0.257477	Test's multi_logloss: 0.362411
# [5720]	Train's multi_logloss: 0.257231	Test's multi_logloss: 0.362381
# [5730]	Train's multi_logloss: 0.257052	Test's multi_logloss: 0.362361
# [5740]	Train's multi_logloss: 0.25678	Test's multi_logloss: 0.362321
# [5750]	Train's multi_logloss: 0.256451	Test's multi_logloss: 0.362264
# [5760]	Train's multi_logloss: 0.256219	Test's multi_logloss: 0.362236
# [5770]	Train's multi_logloss: 0.256045	Test's multi_logloss: 0.362216
# [5780]	Train's multi_logloss: 0.256006	Test's multi_logloss: 0.362228
# [5790]	Train's multi_logloss: 0.255678	Test's multi_logloss: 0.362168
# [5800]	Train's multi_logloss: 0.255658	Test's multi_logloss: 0.362181
# [5810]	Train's multi_logloss: 0.255386	Test's multi_logloss: 0.362146
# [5820]	Train's multi_logloss: 0.255234	Test's multi_logloss: 0.362131
# [5830]	Train's multi_logloss: 0.255202	Test's multi_logloss: 0.362151
# [5840]	Train's multi_logloss: 0.255033	Test's multi_logloss: 0.362145
# [5850]	Train's multi_logloss: 0.25472	Test's multi_logloss: 0.3621
# [5860]	Train's multi_logloss: 0.254396	Test's multi_logloss: 0.362046
# [5870]	Train's multi_logloss: 0.254237	Test's multi_logloss: 0.362029
# [5880]	Train's multi_logloss: 0.253926	Test's multi_logloss: 0.361991
# [5890]	Train's multi_logloss: 0.253847	Test's multi_logloss: 0.361994
# [5900]	Train's multi_logloss: 0.253727	Test's multi_logloss: 0.361983
# [5910]	Train's multi_logloss: 0.253689	Test's multi_logloss: 0.361995
# [5920]	Train's multi_logloss: 0.253541	Test's multi_logloss: 0.361985
# [5930]	Train's multi_logloss: 0.253251	Test's multi_logloss: 0.36195
# [5940]	Train's multi_logloss: 0.253033	Test's multi_logloss: 0.361936
# [5950]	Train's multi_logloss: 0.25288	Test's multi_logloss: 0.361928
# [5960]	Train's multi_logloss: 0.252775	Test's multi_logloss: 0.361935
# [5970]	Train's multi_logloss: 0.252688	Test's multi_logloss: 0.361939
# [5980]	Train's multi_logloss: 0.252621	Test's multi_logloss: 0.361945
# [5990]	Train's multi_logloss: 0.25252	Test's multi_logloss: 0.361945
# [6000]	Train's multi_logloss: 0.252222	Test's multi_logloss: 0.361904

# %%
fig, axs = plt.subplots(1, 2, figsize=[15, 4])

# Plot the log loss during training
axs[0].plot(evaluation_results['Train']['multi_logloss'], label='Train')
axs[0].plot(evaluation_results['Test']['multi_logloss'], label='Test')
axs[0].set_ylabel('Log loss')
axs[0].set_xlabel('Boosting round')
axs[0].set_title('Training performance')
axs[0].legend()

# Plot feature importance
importances = pd.DataFrame({'features': lgmb_model.feature_name(), 
                            'importance': lgmb_model.feature_importance()}).sort_values('importance', ascending=False).head(10)
axs[1].bar(x=np.arange(len(importances)), height=importances['importance'])
axs[1].set_xticks(np.arange(len(importances)))
axs[1].set_xticklabels(importances['features'])
axs[1].set_ylabel('Feature importance (# times used to split)')
axs[1].set_title('Feature importance')
plt.xticks(rotation=45)

plt.show()

# %%
train_y_pred = lgmb_model.predict(X_test)
real_y_pred = lgmb_model.predict(test_X)

# %%
#log_loss
log_loss(y_test,train_y_pred,labels= list(set(y_test)))
# Out:
# 0.3619042859117212

# %%
feature_df = pd.DataFrame(lgmb_model.feature_importance(), index= train_X.columns,columns= ['importance']).sort_values('importance',ascending = False)
feature_df.head(10)
# Out:
#               importance
# modelMag_r-i      118573
# modelMag_g-r      114301
# fiberMag_r-i      110326
# modelMag_u-g      109656
# psfMag_g-r        106009
# psfMag_u-g        103986
# fiberMag_g-r      102470
# modelMag_i-z       96727
# fiberMag_u-g       93220
# psfMag_r           92331

# %%
submission = pd.DataFrame(data=real_y_pred, columns=sample_submission_df.columns, index=sample_submission_df.index)
submission.to_csv(f'submission_lightbgm_tune_outlier_add_only({log_loss(y_test,train_y_pred,labels= list(set(y_test)))}).csv', index=True)

# %% [markdown]
# ## Gridsearch_cv

# %%
# from sklearn.feature_selection import SelectKBest
# model_kbest = SelectKBest()
# from sklearn.pipeline import Pipeline

# %%
# #최적의 변수를 찾기 위한 KBest 함수 불러오기
# #파이프라인 구축
# pipe_lgbm = Pipeline([('lgbm',lgbm_c)])
# #파라미터 생성
# params_lgbm = {
#           "lgbm__max_depth": [15,20,25],
#          "lgbm__learning_rate": [0.001],
#          "lgbm__num_leaves": [15,20,25],
#          "lgbm__n_estimators": [200,300,400,500],
#          "lgbm__random_state": [42]}

# %%
# #최적의 파라미터 탐색
# from sklearn.model_selection import GridSearchCV
# grid_search = GridSearchCV(pipe_lgbm, param_grid = params_lgbm,
# #                           cv=3, n_jobs=-1, verbose=10)

# %%
# grid_search.fit(X_train, y_train)

# %%
# lgbm_grid = grid_search.best_estimator_
# lgbm_grid
